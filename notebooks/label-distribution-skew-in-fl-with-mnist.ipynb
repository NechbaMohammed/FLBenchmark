# %% [markdown]
#  <h2 style="font-size: 34px; font-weight: bold; color: #0E6655; text-align: center; border-bottom: 5px solid #F1C40F; font-family: 'Arial'; padding: 20px; margin-top: 0; box-shadow: 5px 5px 15px #7D8A99; background-color: #FEF5E7; border-radius: 20px;">Addressing Label Distribution Skew in Federated Learning Using the MNIST Dataset</h2>

# %% [markdown]
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 40px; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to bottom right, #D6EAF8, #EBF5FB);">
#     <h2 style="font-size: 34px; font-weight: bold; color: #0E6655; text-align: center; border-bottom: 5px solid #F1C40F; font-family: 'Arial'; padding: 20px; margin-top: 0; box-shadow: 5px 5px 15px #7D8A99; background-color: #FEF5E7; border-radius: 20px;">🎯 Notebook Objective</h2>
#     <p style="font-size: 18px; font-family: 'Calibri'; padding: 20px; line-height: 1.7; color: #34495e;">
#         This notebook examines the performance of various federated learning algorithms under data heterogeneity conditions. We benchmark eight prominent approaches—FedAvg, FedProx, FedNova, FedScaffold, FedMoon, FedAdam, FedAdagrad, and FedYogi—against the MNIST dataset.
#     </p>
#     <ul style="font-size: 18px; font-family: 'Calibri'; padding: 10px 30px; line-height: 1.7; list-style-type: none;">
#         <li>📊 <strong style="color: #0E6655;">Focus Areas:</strong>
#             <ul style="list-style-type: circle; margin-left: 20px;">
#                 <li>Distribution-based label imbalance using Dirichlet allocation</li>
#                 <li>Quantity-based label imbalance where clients possess data from restricted label subsets</li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 40px; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to bottom right, #D6EAF8, #EBF5FB);">
#     <h2 style="font-size: 34px; font-weight: bold; color: #0E6655; text-align: center; border-bottom: 5px solid #F1C40F; font-family: 'Arial'; padding: 20px; margin-top: 0; box-shadow: 5px 5px 15px #7D8A99; background-color: #FEF5E7; border-radius: 20px;">📊 Dataset Story</h2>
#     <ul style="font-size: 18px; font-family: 'Calibri'; padding: 30px; line-height: 1.7; list-style-type: none;">
#         <li>📌 <strong style="color: #0E6655;">Dataset Origin:</strong> This dataset is the MNIST dataset, widely used for image classification tasks. It consists of 60,000 training images and 10,000 testing images.</li>
#         <li>📄 <strong style="color: #0E6655;">Attributes:</strong>
#             <ul>
#                 <li>Image: Grayscale images of handwritten digits with a shape of 28x28 pixels.</li>
#                 <li>Label: The corresponding digit (0-9) for each image.</li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <div style="border: 2px solid #2E86C1;
#             border-radius: 12px;
#             padding: 25px;
#             box-shadow: 0 8px 16px rgba(46, 134, 193, 0.15);
#             background: linear-gradient(145deg, #F8F9FC 0%, #EBF3FA 100%);
#             margin: 25px 0;
#             font-family: 'Segoe UI', sans-serif;">
#     <h1 style="font-size: 28px;
#                font-weight: 600;
#                color: #1B4F72;
#                text-align: center;
#                padding: 15px;
#                margin: 0 0 20px 0;
#                background: #E3F2FD;
#                border-radius: 8px;
#                border-left: 5px solid #2E86C1;
#                box-shadow: 0 4px 6px rgba(27, 79, 114, 0.1);">
#         📚 Table of Contents
#     </h1>
#     <ul style="list-style-type: none; padding-left: 10px;">
#         <li><a href="#1"><strong>I. Dependency Installation</strong></a> <span style="color: #2E86C1; font-size: 0.9em;">→ Core setup requirements</span></li>
#         <li><a href="#2"><strong>II. Library Imports</strong></a> <span style="color: #2E86C1; font-size: 0.9em;">→ Essential package imports</span></li>
#         <li><a href="#3"><strong>III. Implementation</strong></a> <span style="color: #2E86C1; font-size: 0.9em;">→ Core system architecture</span>
#             <ul style="list-style-type: none; padding-left: 20px;">
#                 <li><a href="#31">1. Dataset Loading and Partitioning</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Data preparation pipeline</span></li>
#                 <li><a href="#32">2. Simple CNN Model for MNIST</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Base model architecture</span></li>
#                 <li><a href="#33">3. Federated Learning Algorithms</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Algorithm implementations</span>
#                     <ul style="list-style-type: none; padding-left: 20px;">
#                         <li><a href="#331">A. FedAvg, FedProx, FedAdam</a> <span style="color: #85929E; font-size: 0.8em;">(Standard FL methods)</span>
#                             <ul style="list-style-type: none; padding-left: 20px;">
#                                 <li>a. Training/Testing Pipeline</li>
#                                 <li>b. Flower Client Implementation</li>
#                                 <li>c. Centralized Evaluation</li>
#                             </ul>
#                         </li>
#                         <li><a href="#332">B. FedNova Implementation</a> <span style="color: #85929E; font-size: 0.8em;">(Normalized averaging)</span>
#                             <ul style="list-style-type: none; padding-left: 20px;">
#                                 <li>a. Adapted Model Training</li>
#                                 <li>b. Custom Strategy</li>
#                                 <li>c. Client/Server Setup</li>
#                             </ul>
#                         </li>
#                         <li><a href="#333">C. FedScaffold Implementation</a> <span style="color: #85929E; font-size: 0.8em;">(Control variates)</span>
#                             <ul style="list-style-type: none; padding-left: 20px;">
#                                 <li>a. Optimizer Adaptation</li>
#                                 <li>b. Training Modifications</li>
#                                 <li>c. Strategy Configuration</li>
#                             </ul>
#                         </li>
#                         <li><a href="#334">D. FedMoon Implementation</a> <span style="color: #85929E; font-size: 0.8em;">(Model contrast)</span>
#                             <ul style="list-style-type: none; padding-left: 20px;">
#                                 <li>a. Model Training Adjustments</li>
#                                 <li>b. Client Implementation</li>
#                                 <li>c. Evaluation Framework</li>
#                             </ul>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#         <li><a href="#4"><strong>IV. Simulation Studies</strong></a> <span style="color: #2E86C1; font-size: 0.9em;">→ Experimental scenarios</span>
#             <ul style="list-style-type: none; padding-left: 20px;">
#                 <li><a href="#41">1. Dirichlet Partition (β=0.5)</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Label distribution imbalance</span>
#                     <ul style="list-style-type: none; padding-left: 20px;">
#                         <li>A-H: Run simulations for all implemented algorithms</li>
#                         <li>L: Accuracy Trends</li>
#                     </ul>
#                 </li>
#                 <li><a href="#42">2. Log-Normal (C=1)</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Quantity imbalance I</span>
#                     <ul style="list-style-type: none; padding-left: 20px;">
#                         <li>A-H: Run simulations for all implemented algorithms</li>
#                         <li>L: Accuracy Trends</li>
#                     </ul>
#                 </li>
#                 <li><a href="#43">3. Log-Normal (C=2)</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Quantity imbalance II</span>
#                     <ul style="list-style-type: none; padding-left: 20px;">
#                         <li>A-H: Run simulations for all implemented algorithms</li>
#                         <li>L: Accuracy Trends</li>
#                     </ul>
#                 </li>
#                 <li><a href="#44">4. Log-Normal (C=3)</a> <span style="color: #5D6D7E; font-size: 0.85em;">- Quantity imbalance III</span>
#                     <ul style="list-style-type: none; padding-left: 20px;">
#                         <li>A-H: Run simulations for all implemented algorithms</li>
#                         <li>L: Accuracy Trends</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <a id='1'></a>
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 30px; margin: 30px 0; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to right, #2C3E50, #4CA1AF);">
#     <h1 style="font-size: 34px; font-weight: bold; color: white; text-align: center; font-family: 'Arial'; margin: 0; display: flex; align-items: center; justify-content: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 5px 15px; border-radius: 15px; margin-right: 15px; box-shadow: 3px 3px 10px rgba(0,0,0,0.2);">I</span>
#         <span>Dependency Installation</span>
#     </h1>
# </div>

# %%
# %%capture
# !pip install flwr-datasets[vision] 
# !pip install flwr[simulation]

# %% [markdown]
# <a id='2'></a>
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 30px; margin: 30px 0; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to right, #2C3E50, #4CA1AF);">
#     <h1 style="font-size: 34px; font-weight: bold; color: white; text-align: center; font-family: 'Arial'; margin: 0; display: flex; align-items: center; justify-content: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 5px 15px; border-radius: 15px; margin-right: 15px; box-shadow: 3px 3px 10px rgba(0,0,0,0.2);">II</span>
#         <span>Library Imports</span>
#     </h1>
# </div>

# %%
# Flower function
import flwr as fl
from flwr.common import (
    Metrics,
    NDArray,
    NDArrays,
    Parameters,
    Scalar,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
    FitRes,
    EvaluateRes,
    MetricsAggregationFn,
    FitIns,
    EvaluateIns,
)
from flwr.common.logger import log
from flwr.common.typing import FitRes, GetParametersIns
from flwr.client import Client, ClientApp, NumPyClient
from flwr.server import ServerApp, ServerConfig, ServerAppComponents
from flwr.server.server import FitResultsAndFailures, Server, fit_clients
from flwr.server.client_manager import ClientManager, SimpleClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy.aggregate import aggregate, weighted_loss_avg
from flwr.server.strategy import Strategy
from flwr.server.strategy import FedAvg, FedProx, FedAdam,  FedAdagrad, FedYogi

from flwr.simulation import run_simulation
from flwr.common import Metrics, Context

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import CIFAR10, MNIST, FashionMNIST
from torch.utils.data import DataLoader, random_split, Dataset, Subset, ConcatDataset
from torch.optim import SGD, Optimizer
import torch.optim as optim
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from collections import OrderedDict,Counter
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from typing import Callable, Dict, List, Optional, Tuple, Union
import logging
from logging import DEBUG, INFO,WARNING
import numpy as np
from functools import reduce
from omegaconf import DictConfig
import os
import copy
logging.basicConfig(level=logging.INFO)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# <a id='3'></a>
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 30px; margin: 30px 0; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to right, #2C3E50, #4CA1AF);">
#     <h1 style="font-size: 34px; font-weight: bold; color: white; text-align: center; font-family: 'Arial'; margin: 0; display: flex; align-items: center; justify-content: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 5px 15px; border-radius: 15px; margin-right: 15px; box-shadow: 3px 3px 10px rgba(0,0,0,0.2);">III</span>
#         <span>Implementation</span>
#     </h1>
# </div>

# %% [markdown]
# <a id="31"></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">1</span>
#         <span>Dataset Loading and Partitioning</span>
#     </h2>
# </div>

# %%
class FCubeDataset(Dataset):
    def __init__(self, hf_dataset):
        self.hf_dataset = hf_dataset
        # Extract all targets upfront for partitioning logic
        self.targets = torch.tensor(hf_dataset['targets'], dtype=torch.long)
        
    def __len__(self):
        return len(self.hf_dataset)

    def __getitem__(self, idx):
        sample = self.hf_dataset[idx]
        # Stack features into a tensor and return with target
        data = torch.stack([
            torch.tensor(sample['feature_1'], dtype=torch.float32),
            torch.tensor(sample['feature_2'], dtype=torch.float32),
            torch.tensor(sample['feature_3'], dtype=torch.float32)
        ], dim=0)
        return data, self.targets[idx]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class FederatedDataset:
    def __init__(self, config: DictConfig, num_clients: int, val_ratio: float = 0.1, seed: Optional[int] = 42):
        self.config = config
        self.num_clients = num_clients
        self.val_ratio = val_ratio
        self.seed = seed
        self.trainset, self.testset = self._download_data(config.name)
        self.datasets = self._partition_data()

    def _download_data(self, dataset_name: str) -> Tuple[Dataset, Dataset]:
        """Download the requested dataset."""
        if dataset_name == "cifar10":
            normalize = transforms.Normalize(
                mean=[x / 255.0 for x in [125.3, 123.0, 113.9]],
                std=[x / 255.0 for x in [63.0, 62.1, 66.7]],
            )
            
            transform_train = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Lambda(
                        lambda x: F.pad(
                            x.unsqueeze(0),  # No need to wrap in Variable
                            (4, 4, 4, 4),
                            mode="reflect",
                        ).data.squeeze()
                    ),
                    transforms.ToPILImage(),
                    transforms.ColorJitter(brightness=0),
                    transforms.RandomCrop(32),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    normalize,
                ]
            )
            
            # Data prep for test set
            transform_test = transforms.Compose([transforms.ToTensor(), normalize])
            # data prep for test set            
            trainset = CIFAR10(root="data", train=True, download=True, transform=transform_train)
            testset = CIFAR10(root="data", train=False, download=True, transform=transform_test)
        elif dataset_name == "mnist":
            transform_train = transforms.Compose([transforms.ToTensor()])
            transform_test = transforms.Compose([transforms.ToTensor()])
            trainset = MNIST(root="data", train=True, download=True, transform=transform_train)
            testset = MNIST(root="data", train=False, download=True, transform=transform_test)
        elif dataset_name == "fmnist":
            transform_train = transforms.Compose([transforms.ToTensor()])
            transform_test = transforms.Compose([transforms.ToTensor()])
            trainset = FashionMNIST(root="data", train=True, download=True, transform=transform_train)
            testset = FashionMNIST(root="data", train=False, download=True, transform=transform_test)
        elif dataset_name == "fcube":
            dataset = load_dataset("Nechba/fcube")
            if 'target' in dataset['train'].column_names:
                dataset = dataset.rename_column('target', 'targets')
            trainset = FCubeDataset(dataset['train'])
            testset = FCubeDataset(dataset['test'])
        elif dataset_name == "svhn":
            dataset = load_dataset("ufldl-stanford/svhn")
            trainset = dataset['train']
            testset = dataset['test']
        else:
            raise NotImplementedError(f"Dataset {dataset_name} not supported.")
        return trainset, testset

    def _partition_data(self) -> Tuple[List[Dataset], Dataset]:
        """Partition the dataset according to the specified method."""
        partitioning = self.config.get("partitioning", "")
        if partitioning == "dirichlet":
            alpha = self.config.get("alpha", 0.5)
            return self._partition_data_dirichlet(alpha)
        elif partitioning == "label_quantity":
            labels_per_client = self.config.get("labels_per_client", 2)
            return self._partition_data_label_quantity(labels_per_client)
        elif partitioning == "iid":
            return self._partition_data_iid()
        elif partitioning == "iid_noniid":
            similarity = self.config.get("similarity", 0.5)
            return self._partition_data_iid_noniid(similarity)
        else:
            raise ValueError(f"Partitioning method {partitioning} not supported.")

    def _partition_data_dirichlet(self, alpha: float) -> Tuple[List[Dataset], Dataset]:
        """Partition according to the Dirichlet distribution."""
        min_required_samples_per_client = 10
        min_samples = 0
        prng = np.random.default_rng(self.seed)
        # Access targets from Hugging Face Dataset
        if isinstance(self.trainset, FCubeDataset):
            tmp_t = self.trainset.targets.numpy()  # Alre
        else:  # Handle PyTorch datasets
            tmp_t = self.trainset.targets
            if isinstance(tmp_t, list):
                tmp_t = np.array(tmp_t)
            if isinstance(tmp_t, torch.Tensor):
                tmp_t = tmp_t.numpy()
        num_classes = len(set(tmp_t))
        total_samples = len(tmp_t)
        idx_clients: List[List] = [[] for _ in range(self.num_clients)]
        while min_samples < min_required_samples_per_client:
            for k in range(num_classes):
                idx_k = np.where(tmp_t == k)[0]
                prng.shuffle(idx_k)
                proportions = prng.dirichlet(np.repeat(alpha, self.num_clients))
                proportions = np.array([p * (len(idx_j) < total_samples / self.num_clients) for p, idx_j in zip(proportions, idx_clients)])
                proportions = proportions / proportions.sum()
                proportions = (np.cumsum(proportions) * len(idx_k)).astype(int)[:-1]
                idx_k_split = np.split(idx_k, proportions)
                idx_clients = [idx_j + idx.tolist() for idx_j, idx in zip(idx_clients, idx_k_split)]
                min_samples = min([len(idx_j) for idx_j in idx_clients])
        trainsets_per_client = [Subset(self.trainset, idxs) for idxs in idx_clients]
        return trainsets_per_client, self.testset

    def _partition_data_label_quantity(self, labels_per_client: int) -> Tuple[List[Dataset], Dataset]:
        """Partition the data according to the number of labels per client."""
        prng = np.random.default_rng(self.seed)
        targets = self.trainset.targets
        if isinstance(targets, list):
            targets = np.array(targets)
        if isinstance(targets, torch.Tensor):
            targets = targets.numpy()
        num_classes = len(set(targets))
        times = [0 for _ in range(num_classes)]
        contains = []
        for i in range(self.num_clients):
            current = [i % num_classes]
            times[i % num_classes] += 1
            j = 1
            while j < labels_per_client:
                index = prng.choice(num_classes, 1)[0]
                if index not in current:
                    current.append(index)
                    times[index] += 1
                    j += 1
            contains.append(current)
        idx_clients: List[List] = [[] for _ in range(self.num_clients)]
        for i in range(num_classes):
            idx_k = np.where(targets == i)[0]
            prng.shuffle(idx_k)
            idx_k_split = np.array_split(idx_k, times[i])
            ids = 0
            for j in range(self.num_clients):
                if i in contains[j]:
                    idx_clients[j] += idx_k_split[ids].tolist()
                    ids += 1
        trainsets_per_client = [Subset(self.trainset, idxs) for idxs in idx_clients]
        return trainsets_per_client, self.testset

    def _partition_data_iid(self) -> Tuple[List[Dataset], Dataset]:
        """Partition the data in an IID manner."""
        return self._partition_data_iid_noniid(similarity=1.0)

    def _partition_data_iid_noniid(self, similarity: float) -> Tuple[List[Dataset], Dataset]:
        """Partition the data in a mixed IID and non-IID manner."""
        trainsets_per_client = []
        s_fraction = int(similarity * len(self.trainset))
        prng = np.random.default_rng(self.seed)
        idxs = prng.choice(len(self.trainset), s_fraction, replace=False)
        iid_trainset = Subset(self.trainset, idxs)
        rem_trainset = Subset(self.trainset, np.setdiff1d(np.arange(len(self.trainset)), idxs))
        all_ids = np.arange(len(iid_trainset))
        splits = np.array_split(all_ids, self.num_clients)
        for i in range(self.num_clients):
            c_ids = splits[i]
            d_ids = iid_trainset.indices[c_ids]
            trainsets_per_client.append(Subset(iid_trainset.dataset, d_ids))
        if similarity == 1.0:
            return trainsets_per_client, self.testset
        tmp_t = rem_trainset.dataset.targets
        if isinstance(tmp_t, list):
            tmp_t = np.array(tmp_t)
        if isinstance(tmp_t, torch.Tensor):
            tmp_t = tmp_t.numpy()
        targets = tmp_t[rem_trainset.indices]
        num_remaining_classes = len(set(targets))
        remaining_classes = list(set(targets))
        client_classes: List[List] = [[] for _ in range(self.num_clients)]
        times = [0 for _ in range(num_remaining_classes)]
        for i in range(self.num_clients):
            client_classes[i] = [remaining_classes[i % num_remaining_classes]]
            times[i % num_remaining_classes] += 1
            j = 1
            while j < 2:
                index = prng.choice(num_remaining_classes)
                class_t = remaining_classes[index]
                if class_t not in client_classes[i]:
                    client_classes[i].append(class_t)
                    times[index] += 1
                    j += 1
        rem_trainsets_per_client: List[List] = [[] for _ in range(self.num_clients)]
        for i in range(num_remaining_classes):
            class_t = remaining_classes[i]
            idx_k = np.where(targets == i)[0]
            prng.shuffle(idx_k)
            idx_k_split = np.array_split(idx_k, times[i])
            ids = 0
            for j in range(self.num_clients):
                if class_t in client_classes[j]:
                    act_idx = rem_trainset.indices[idx_k_split[ids]]
                    rem_trainsets_per_client[j].append(Subset(rem_trainset.dataset, act_idx))
                    ids += 1
        for i in range(self.num_clients):
            trainsets_per_client[i] = ConcatDataset([trainsets_per_client[i]] + rem_trainsets_per_client[i])
        return trainsets_per_client, self.testset

    def get_dataloaders(self) -> Tuple[List[DataLoader], List[DataLoader], DataLoader]:
        """Create the dataloaders to be fed into the model."""
        batch_size = self.config.get("batch_size", -1)
        batch_size_ratio = self.config.get("batch_size_ratio", None)
        trainloaders = []
        valloaders = []
        for dataset in self.datasets[0]:
            len_val = int(len(dataset) / (1 / self.val_ratio)) if self.val_ratio > 0 else 0
            lengths = [len(dataset) - len_val, len_val]
            ds_train, ds_val = random_split(dataset, lengths, torch.Generator().manual_seed(self.seed))
            if batch_size == -1 and batch_size_ratio is not None:
                batch_size = int(len(ds_train) * batch_size_ratio)
            trainloaders.append(DataLoader(ds_train, batch_size=batch_size, shuffle=True))
            valloaders.append(DataLoader(ds_val, batch_size=batch_size))
        return trainloaders, valloaders, DataLoader(self.datasets[1], batch_size=len(self.datasets[1]))

# %%
class DatasetStatistics:
    def __init__(self, fed_dataset: FederatedDataset):
        self.fed_dataset = fed_dataset
    
    def compute_statistics(self):
        stats = {}
        
        # Global dataset statistics
        trainset_size = len(self.fed_dataset.trainset)
        testset_size = len(self.fed_dataset.testset)
        stats["Total Training Samples"] = trainset_size
        stats["Total Test Samples"] = testset_size
        
        # Client-wise statistics
        client_stats = {}
        for i, client_dataset in enumerate(self.fed_dataset.datasets[0]):
            labels = [label for _, label in client_dataset]
            label_counts = dict(Counter(labels))
            client_stats[f"Client {i}"] = {
                "Num Samples": len(client_dataset),
                "Label Distribution": label_counts
            }
        stats["Client Statistics"] = client_stats
        
        # Testset statistics
        test_labels = [label for _, label in self.fed_dataset.testset]
        stats["Test Label Distribution"] = dict(Counter(test_labels))
        
        return stats
    
    def display_statistics(self):
        stats = self.compute_statistics()
        print("Dataset Statistics:")
        for key, value in stats.items():
            if isinstance(value, dict):
                print(f"\n{key}:")
                for sub_key, sub_value in value.items():
                    print(f"  {sub_key}: {sub_value}")
            else:
                print(f"{key}: {value}")
    
    def plot_statistics(self, figsize=(20, 15)):
        """
        Generate visualizations for the dataset statistics
        
        Args:
            figsize (tuple): Figure size for the plots
        """
        stats = self.compute_statistics()
        
        # Create a figure with subplots
        fig = plt.figure(figsize=figsize)
        
        # 1. Distribution of samples across clients
        plt.subplot(2, 2, 1)
        client_samples = [stats["Client Statistics"][f"Client {i}"]["Num Samples"] 
                          for i in range(len(stats["Client Statistics"]))]
        plt.bar(range(len(client_samples)), client_samples)
        plt.title("Sample Distribution Across Clients")
        plt.xlabel("Client ID")
        plt.ylabel("Number of Samples")
        plt.xticks(range(len(client_samples)), [f"Client {i}" for i in range(len(client_samples))])
        plt.grid(True, alpha=0.3)
        
        # 2. Label distribution in test dataset
        plt.subplot(2, 2, 2)
        test_labels = stats["Test Label Distribution"]
        labels = sorted(test_labels.keys())
        counts = [test_labels[label] for label in labels]
        plt.bar(labels, counts)
        plt.title("Test Dataset Label Distribution")
        plt.xlabel("Label")
        plt.ylabel("Count")
        plt.grid(True, alpha=0.3)
        
        # 3. Heatmap of label distribution across clients
        plt.subplot(2, 1, 2)
        
        # Get all unique labels
        all_labels = set()
        for client in stats["Client Statistics"].values():
            all_labels.update(client["Label Distribution"].keys())
        all_labels = sorted(list(all_labels))
        
        # Create a matrix for the heatmap
        heatmap_data = np.zeros((len(stats["Client Statistics"]), len(all_labels)))
        
        # Fill the matrix
        for i, client_id in enumerate(range(len(stats["Client Statistics"]))):
            client_key = f"Client {client_id}"
            client_labels = stats["Client Statistics"][client_key]["Label Distribution"]
            for j, label in enumerate(all_labels):
                heatmap_data[i, j] = client_labels.get(label, 0)
        
        # Normalize by row (client)
        row_sums = heatmap_data.sum(axis=1, keepdims=True)
        heatmap_data_normalized = heatmap_data / row_sums
        
        # Plot heatmap
        sns.heatmap(heatmap_data_normalized, annot=True, fmt=".2f", cmap="YlGnBu",
                    xticklabels=all_labels, yticklabels=[f"Client {i}" for i in range(len(stats["Client Statistics"]))])
        plt.title("Normalized Label Distribution Across Clients")
        plt.xlabel("Label")
        plt.ylabel("Client")
        
        plt.tight_layout()
        plt.savefig("dataset_statistics.png")
        plt.show()

# %% [markdown]
# <a id='32'></a>
#
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">2</span>
#         <span>Simple CNN Model for MNIST</span>
#     </h2>
# </div>

# %%
class CNN(nn.Module):
    """Implement a CNN model for MNIST and Fashion-MNIST.

    Parameters
    ----------
    input_dim : int
        The input dimension for classifier.
    hidden_dims : List[int]
        The hidden dimensions for classifier.
    num_classes : int
        The number of classes in the dataset.
    """

    def __init__(self, input_dim, hidden_dims, num_classes) -> None:
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)

        self.fc1 = nn.Linear(input_dim, hidden_dims[0])
        self.fc2 = nn.Linear(hidden_dims[0], hidden_dims[1])
        self.fc3 = nn.Linear(hidden_dims[1], num_classes)

    def forward(self, x):
        """Implement forward pass."""
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))

        x = x.view(-1, 16 * 4 * 4)

        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class SimpleCNNHeader(nn.Module):
    """Simple CNN model."""

    def __init__(self, input_dim, hidden_dims):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)

        self.fc1 = nn.Linear(input_dim, hidden_dims[0])
        self.fc2 = nn.Linear(hidden_dims[0], hidden_dims[1])

    def forward(self, x):
        """Forward."""
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 16 * 4 * 4)

        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        # x = self.fc3(x)
        return x

# %%
class ModelMOON(nn.Module):
    """Model for MOON."""

    def __init__(self, input_dim,hidden_dims, out_dim, n_classes):
        super().__init__()

        
        self.features = SimpleCNNHeader(
                input_dim=input_dim, hidden_dims=hidden_dims
            )
        num_ftrs = 84

        # projection MLP
        self.l1 = nn.Linear(num_ftrs, num_ftrs)
        self.l2 = nn.Linear(num_ftrs, out_dim)

        # last layer
        self.l3 = nn.Linear(out_dim, n_classes)

    def _get_basemodel(self, model_name):
        try:
            model = self.model_dict[model_name]
            return model
        except KeyError as err:
            raise ValueError("Invalid model name.") from err

    def forward(self, x):
        """Forward."""
        h = self.features(x)
        #h = h.squeeze()
        x = self.l1(h)
        x = F.relu(x)
        x = self.l2(x)

        y = self.l3(x)
        return h, x, y


def init_net(input_dim,hidden_dims, output_dim, n_classes, device):
    """Initialize model."""
   
    net = ModelMOON(input_dim,hidden_dims, output_dim, n_classes)
    net.to(device)

    return net

# %% [markdown]
# <a id='33'></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">3</span>
#         <span>Implementation of Federated Learning Algorithms</span>
#     </h2>
# </div>

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">A</span>
#         <span>Implementation of Federated Learning Methods: FedAvg, FedProx, FedAdam, FedAdagrad, and FedYogi</span>
#     </h3>
# </div>

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">a</span>
#         <span>Implementation of Training and Testing Phases for a CNN Model</span>
#     </h4>
# </div>

# %%
def train(net, trainloader, epochs: int,device: torch.device,  verbose=False):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for epoch in range(epochs):
        correct, total, epoch_loss = 0, 0, 0.0
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            outputs = net(data)
            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()
            # Metrics
            epoch_loss += loss
            total += target.size(0)
            correct += (torch.max(outputs.data, 1)[1] == target).sum().item()
        epoch_loss /= len(trainloader.dataset)
        epoch_acc = correct / total
        if verbose:
            print(f"Epoch {epoch+1}: train loss {epoch_loss}, accuracy {epoch_acc}")

# %%
def compute_accuracy(model, dataloader, device):
    """Compute accuracy."""
    criterion = nn.CrossEntropyLoss(reduction="sum")
    model.eval()
    correct, total, loss = 0, 0, 0.0
    with torch.no_grad():
        for data, target in dataloader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss += criterion(output, target).item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    loss = loss / total
    acc = correct / total

    return  loss, acc

# %%
def test(net, test_dataloader, device):
    """Test function."""
    net.to(device)
    loss, test_acc = compute_accuracy(net, test_dataloader, device=device)
    #print(">> Test accuracy: %f" % test_acc)
    net.to("cpu")
    return loss, test_acc

# %% [markdown]
# <a id='332'></a>
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">b</span>
#         <span>Implementation of the Flower Client </span>
#     </h4>
# </div>

# %%
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, valloader, device: torch.device,epochs):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader
        self.device = device
        self.epochs = epochs

    def get_parameters(self, config):
        return [val.cpu().numpy() for _, val in self.net.state_dict().items()]
        
    def set_parameters(self, parameters):
        """Set the local model parameters using given ones."""
        params_dict = zip(self.net.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.net.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config):
        self.set_parameters( parameters)
        train(self.net, self.trainloader, epochs=self.epochs, device = self.device)
        return self.get_parameters(config), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        self.set_parameters( parameters)
        loss, accuracy = test(self.net, self.valloader, device= self.device)
        return (
            float(loss),
            len(self.valloader.dataset),  # num_examples
            {"accuracy": float(accuracy)}  # metrics
        )

# %%
def gen_client_fn(
    trainloaders: List[DataLoader],
    valloaders: List[DataLoader],
     model_cfg: DictConfig,
    device: torch.device,
    epochs
) -> Callable[[str], FlowerClient]:  
    

    def client_fn(context: Context) -> FlowerClient:
        """Create a Flower client representing a single organization."""
        # Load model
        net = CNN(model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
        net.to(device)
        cid = context.node_config["partition-id"]
       
        trainloader = trainloaders[int(cid)]
        valloader = valloaders[int(cid)]

        return FlowerClient(
            net,
            trainloader,
            valloader,
             device,
            epochs
        ).to_client()

    return client_fn

# %% [markdown]
# <a id='333'></a>
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">c</span>
#         <span>Implementation of the Centralized Evaluation Function</span>
#     </h4>
# </div>

# %%
def gen_evaluate_fn(
    testloader: DataLoader,
    device: torch.device,
    model_cfg: DictConfig,
) -> Callable[
    [int, NDArrays, Dict[str, Scalar]], Optional[Tuple[float, Dict[str, Scalar]]]
]:
    """Generate the function for centralized evaluation.

    Parameters
    ----------
    testloader : DataLoader
        The dataloader to test the model with.
    device : torch.device
        The device to test the model on.

    Returns
    -------
    Callable[ [int, NDArrays, Dict[str, Scalar]],
               Optional[Tuple[float, Dict[str, Scalar]]] ]
    The centralized evaluation function.
    """

    def evaluate(
        server_round: int, parameters_ndarrays: NDArrays, config: Dict[str, Scalar]
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        # pylint: disable=unused-argument
        """Use the entire Emnist test set for evaluation."""
        net = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
        params_dict = zip(net.state_dict().keys(), parameters_ndarrays)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        net.load_state_dict(state_dict, strict=True)
        net.to(device)

        loss, accuracy = test(net, testloader, device)
        return loss, {"test_accuracy": accuracy}

    return evaluate

# %% [markdown]
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">B</span>
#         <span>Implementation of FedNova</span>
#     </h3>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">a</span>
#         <span>Implementation of CNN Model Training Adapted for FedNova</span>
#     </h4>
# </div>

# %%
def train_fednova(
    net: nn.Module,
    trainloader: DataLoader,
    device: torch.device,
    epochs: int,
    learning_rate: float,
    momentum: float,
    weight_decay: float,
) -> Tuple[float, List[torch.Tensor]]:
    # pylint: disable=too-many-arguments
    """Train the network on the training set using FedNova.

    Parameters
    ----------
    net : nn.Module
        The neural network to train.
    trainloader : DataLoader
        The training set dataloader object.
    device : torch.device
        The device on which to train the network.
    epochs : int
        The number of epochs to train the network.
    learning_rate : float
        The learning rate.
    momentum : float
        The momentum for SGD optimizer.
    weight_decay : float
        The weight decay for SGD optimizer.

    Returns
    -------
    tuple[float, List[torch.Tensor]]
        The a_i and g_i values.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = SGD(
        net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay
    )
    net.train()
    local_steps = 0
    # clone all the parameters
    prev_net = [param.detach().clone() for param in net.parameters()]
    for _ in range(epochs):
        net, local_steps = _train_one_epoch_fednova(
            net, trainloader, device, criterion, optimizer, local_steps
        )
    # compute ||a_i||_1
    a_i = (
        local_steps - (momentum * (1 - momentum**local_steps) / (1 - momentum))
    ) / (1 - momentum)
    # compute g_i
    g_i = [
        torch.div(prev_param - param.detach(), a_i)
        for prev_param, param in zip(prev_net, net.parameters())
    ]

    return a_i, g_i

# %%
def _train_one_epoch_fednova(
    net: nn.Module,
    trainloader: DataLoader,
    device: torch.device,
    criterion: nn.Module,
    optimizer: Optimizer,
    local_steps: int,
) -> Tuple[nn.Module, int]:
    # pylint: disable=too-many-arguments
    """Train the network on the training set for one epoch."""
    for data, target in trainloader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        local_steps += 1
    return net, local_steps

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">b</span>
#         <span> Implementation of the FedNova strategy </span>
#     </h4>
# </div>

# %%
class FedNovaStrategy(FedAvg):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)  # Initialize the parent class

    def aggregate_fit_custom(
        self,
        server_round: int,
        server_params: NDArrays,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[Union[Tuple[ClientProxy, FitRes], BaseException]],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        """Aggregate fit results using weighted average."""
        if not results:
            return None, {}
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            return None, {}

        # Convert results
        weights_results = [
            (parameters_to_ndarrays(fit_res.parameters), fit_res.num_examples)
            for _, fit_res in results
        ]
        total_samples = sum([fit_res.num_examples for _, fit_res in results])
        c_fact = sum(
            [
                float(fit_res.metrics["a_i"]) * fit_res.num_examples / total_samples
                for _, fit_res in results
            ]
        )
        new_weights_results = [
            (result[0], c_fact * (fit_res.num_examples / total_samples))
            for result, (_, fit_res) in zip(weights_results, results)
        ]

        # Aggregate grad updates, t_eff*(sum_i(p_i*\eta*d_i))
        grad_updates_aggregated = aggregate_fednova(new_weights_results)
        # Final parameters = server_params - grad_updates_aggregated
        aggregated = [
            server_param - grad_update
            for server_param, grad_update in zip(server_params, grad_updates_aggregated)
        ]

        parameters_aggregated = ndarrays_to_parameters(aggregated)
        # Aggregate custom metrics if aggregation fn was provided
        metrics_aggregated = {}
        if self.fit_metrics_aggregation_fn:
            fit_metrics = [(res.num_examples, res.metrics) for _, res in results]
            metrics_aggregated = self.fit_metrics_aggregation_fn(fit_metrics)
        elif server_round == 1:  # Only log this warning once
            log(WARNING, "No fit_metrics_aggregation_fn provided")

        return parameters_aggregated, metrics_aggregated



def aggregate_fednova(results: List[Tuple[NDArrays, float]]) -> NDArrays:
    """Implement custom aggregate function for FedNova."""
    # Create a list of weights, each multiplied by the weight_factor
    weighted_weights = [
        [layer * factor for layer in weights] for weights, factor in results
    ]

    # Compute average weights of each layer
    weights_prime: NDArrays = [
        reduce(np.add, layer_updates) for layer_updates in zip(*weighted_weights)
    ]
    return weights_prime

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">c</span>
#         <span>Implementation of FedNova Flower client</span>
#     </h4>
# </div>

# %%
# pylint: disable=too-many-instance-attributes
class FlowerClientFedNova(fl.client.NumPyClient):

    # pylint: disable=too-many-arguments
    def __init__(
        self,
        net: torch.nn.Module,
        trainloader: DataLoader,
        valloader: DataLoader,
        device: torch.device,
        num_epochs: int,
        learning_rate: float,
        momentum: float,
        weight_decay: float,
    ) -> None:
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader
        self.device = device
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.weight_decay = weight_decay

    def get_parameters(self, config: Dict[str, Scalar]):
        """Return the current local model parameters."""
        return [val.cpu().numpy() for _, val in self.net.state_dict().items()]

    def set_parameters(self, parameters):
        """Set the local model parameters using given ones."""
        params_dict = zip(self.net.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.net.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config: Dict[str, Scalar]):
        """Implement distributed fit function for a given client for FedNova."""
        self.set_parameters(parameters)
        a_i, g_i = train_fednova(
            self.net,
            self.trainloader,
            self.device,
            self.num_epochs,
            self.learning_rate,
            self.momentum,
            self.weight_decay,
        )
        # final_p_np = self.get_parameters({})
        g_i_np = [param.cpu().numpy() for param in g_i]
        return g_i_np, len(self.trainloader.dataset), {"a_i": a_i}

    def evaluate(self, parameters, config: Dict[str, Scalar]):
        """Evaluate using given parameters."""
        self.set_parameters(parameters)
        loss, acc = test(self.net, self.valloader, self.device)
        return float(loss), len(self.valloader.dataset), {"accuracy": float(acc)}

# %%
def nova_gen_client_fn(
    trainloaders: List[DataLoader],
    valloaders: List[DataLoader],
     model_cfg: DictConfig,
    device: torch.device,
    num_epochs: int,
    learning_rate: float,
    momentum: float = 0.9,
    weight_decay: float = 1e-5,
    
) -> Callable[[str], FlowerClientFedNova]:  # pylint: disable=too-many-arguments
    """Generate the client function that creates the FedNova flower clients.

    Parameters
    ----------
    trainloaders: List[DataLoader]
        A list of DataLoaders, each pointing to the dataset training partition
        belonging to a particular client.
    valloaders: List[DataLoader]
        A list of DataLoaders, each pointing to the dataset validation partition
        belonging to a particular client.
    num_epochs : int
        The number of local epochs each client should run the training for before
        sending it to the server.
    learning_rate : float
        The learning rate for the SGD  optimizer of clients.
    model : DictConfig
        The model configuration.
    momentum : float
        The momentum for SGD optimizer of clients
    weight_decay : float
        The weight decay for SGD optimizer of clients

    Returns
    -------
    Callable[[str], FlowerClientFedNova]
        The client function that creates the FedNova flower clients
    """

    def client_fn(context: Context) -> FlowerClientFedNova:
        """Create a Flower client representing a single organization."""
        # Load model
        net = CNN(model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
        
        cid = context.node_config["partition-id"]
        trainloader = trainloaders[int(cid)]
        valloader = valloaders[int(cid)]

        return FlowerClientFedNova(
            net,
            trainloader,
            valloader,
            device,
            num_epochs,
            learning_rate,
            momentum,
            weight_decay,
        ).to_client()

    return client_fn

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">d</span>
#         <span>Implementation of FedNova server</span>
#     </h4>
# </div>

# %%
class FedNovaServer(Server):
    """Implement server for FedNova."""

    def __init__(
        self,
        *,
        client_manager: ClientManager,
        strategy: Optional[FedNovaStrategy] = None,
    ) -> None:
        super().__init__(client_manager=client_manager, strategy=strategy)
        self.strategy: FedNovaStrategy = (
            strategy if strategy is not None else FedNovaStrategy()
        )

    def fit_round(
        self,
        server_round: int,
        timeout: Optional[float],
    ) -> Optional[
        Tuple[Optional[Parameters], Dict[str, Scalar], FitResultsAndFailures]
    ]:
        """Perform a single round of federated averaging."""
        # Get clients and their respective instructions from strategy
        client_instructions = self.strategy.configure_fit(
            server_round=server_round,
            parameters=self.parameters,
            client_manager=self._client_manager,
        )

        if not client_instructions:
            log(INFO, "fit_round %s: no clients selected, cancel", server_round)
            return None
        log(
            DEBUG,
            "fit_round %s: strategy sampled %s clients (out of %s)",
            server_round,
            len(client_instructions),
            self._client_manager.num_available(),
        )

        # Collect `fit` results from all clients participating in this round
        results, failures = fit_clients(
            client_instructions=client_instructions,
            max_workers=self.max_workers,
            timeout=timeout,
             group_id=str(server_round)
        )
        log(
            DEBUG,
            "fit_round %s received %s results and %s failures",
            server_round,
            len(results),
            len(failures),
        )

        params_np = parameters_to_ndarrays(self.parameters)
        # Aggregate training results
        aggregated_result: Tuple[
            Optional[Parameters],
            Dict[str, Scalar],
        ] = self.strategy.aggregate_fit_custom(
            server_round, params_np, results, failures
        )

        parameters_aggregated, metrics_aggregated = aggregated_result
        return parameters_aggregated, metrics_aggregated, (results, failures)

# %% [markdown]
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>Implementation of FedScaffold</span>
#     </h3>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">a</span>
#         <span>Implementation of SGD Optimizer Adapted for SCAFFOLD</span>
#     </h4>
# </div>

# %%
class ScaffoldOptimizer(SGD):
    """Implements SGD optimizer step function as defined in the SCAFFOLD paper."""

    def __init__(self, grads, step_size, momentum, weight_decay):
        super().__init__(
            grads, lr=step_size, momentum=momentum, weight_decay=weight_decay
        )

    def step_custom(self, server_cv, client_cv):
        """Implement the custom step function fo SCAFFOLD."""
        # y_i = y_i - \eta * (g_i + c - c_i)  -->
        # y_i = y_i - \eta*(g_i + \mu*b_{t}) - \eta*(c - c_i)
        self.step()
        for group in self.param_groups:
            for par, s_cv, c_cv in zip(group["params"], server_cv, client_cv):
                par.data.add_(s_cv - c_cv, alpha=-group["lr"])

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">b</span>
#         <span>Implementation of CNN Model Training Adapted for SCAFFOLD</span>
#     </h4>
# </div>

# %%
def train_scaffold(
    net: nn.Module,
    trainloader: DataLoader,
    device: torch.device,
    epochs: int,
    learning_rate: float,
    momentum: float,
    weight_decay: float,
    server_cv: torch.Tensor,
    client_cv: torch.Tensor,
) -> None:
    # pylint: disable=too-many-arguments
    """Train the network on the training set using SCAFFOLD.

    Parameters
    ----------
    net : nn.Module
        The neural network to train.
    trainloader : DataLoader
        The training set dataloader object.
    device : torch.device
        The device on which to train the network.
    epochs : int
        The number of epochs to train the network.
    learning_rate : float
        The learning rate.
    momentum : float
        The momentum for SGD optimizer.
    weight_decay : float
        The weight decay for SGD optimizer.
    server_cv : torch.Tensor
        The server's control variate.
    client_cv : torch.Tensor
        The client's control variate.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = ScaffoldOptimizer(
        net.parameters(), learning_rate, momentum, weight_decay
    )
    net.train()
    for _ in range(epochs):
        net = _train_one_epoch_scaffold(
            net, trainloader, device, criterion, optimizer, server_cv, client_cv
        )

# %%
def _train_one_epoch_scaffold(
    net: nn.Module,
    trainloader: DataLoader,
    device: torch.device,
    criterion: nn.Module,
    optimizer: ScaffoldOptimizer,
    server_cv: torch.Tensor,
    client_cv: torch.Tensor,
) -> nn.Module:
    # pylint: disable=too-many-arguments
    """Train the network on the training set for one epoch."""
    for data, target in trainloader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=1.0)
       
        optimizer.step_custom(server_cv, client_cv)
    return net

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">c</span>
#         <span> Implementation of the FedScaffold strategy </span>
#     </h4>
# </div>

# %%
class ScaffoldStrategy(FedAvg):
    """Implement custom strategy for SCAFFOLD based on FedAvg class."""

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[Union[Tuple[ClientProxy, FitRes], BaseException]],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        """Aggregate fit results using weighted average."""
        if not results:
            return None, {}
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            return None, {}

        combined_parameters_all_updates = [
            parameters_to_ndarrays(fit_res.parameters) for _, fit_res in results
        ]
        len_combined_parameter = len(combined_parameters_all_updates[0])
        num_examples_all_updates = [fit_res.num_examples for _, fit_res in results]
        # Zip parameters and num_examples
        weights_results = [
            (update[: len_combined_parameter // 2], num_examples)
            for update, num_examples in zip(
                combined_parameters_all_updates, num_examples_all_updates
            )
        ]
        # Aggregate parameters
        parameters_aggregated = aggregate(weights_results)

        # Zip client_cv_updates and num_examples
        client_cv_updates_and_num_examples = [
            (update[len_combined_parameter // 2 :], num_examples)
            for update, num_examples in zip(
                combined_parameters_all_updates, num_examples_all_updates
            )
        ]
        aggregated_cv_update = aggregate(client_cv_updates_and_num_examples)

        # Aggregate custom metrics if aggregation fn was provided
        metrics_aggregated = {}
        if self.fit_metrics_aggregation_fn:
            fit_metrics = [(res.num_examples, res.metrics) for _, res in results]
            metrics_aggregated = self.fit_metrics_aggregation_fn(fit_metrics)
        elif server_round == 1:  # Only log this warning once
            log(WARNING, "No fit_metrics_aggregation_fn provided")

        return (
            ndarrays_to_parameters(parameters_aggregated + aggregated_cv_update),
            metrics_aggregated
        )

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">d</span>
#         <span> Implementation of FedScaffold Flower client </span>
#     </h4>
# </div>

# %%
class FlowerClientScaffold(fl.client.NumPyClient):
    """Flower client implementing scaffold."""

    # pylint: disable=too-many-arguments
    def __init__(
        self,
        cid: int,
        net: torch.nn.Module,
        trainloader: DataLoader,
        valloader: DataLoader,
        device: torch.device,
        num_epochs: int,
        learning_rate: float,
        momentum: float,
        weight_decay: float,
        save_dir: str = "",
    ) -> None:
        self.cid = cid
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader
        self.device = device
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.weight_decay = weight_decay
        # initialize client control variate with 0 and shape of the network parameters
        self.client_cv = []
        for param in self.net.parameters():
            self.client_cv.append(torch.zeros(param.shape))
        # save cv to directory
        if save_dir == "":
            save_dir = "client_cvs"
        self.dir = save_dir
        if not os.path.exists(self.dir):
            os.makedirs(self.dir)

    def get_parameters(self, config: Dict[str, Scalar]):
        """Return the current local model parameters."""
        return [val.cpu().numpy() for _, val in self.net.state_dict().items()]

    def set_parameters(self, parameters):
        """Set the local model parameters using given ones."""
        params_dict = zip(self.net.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.net.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config: Dict[str, Scalar]):
        # Split parameters into model weights and server_cv
        model_weights = parameters[: len(parameters) // 2]
        server_cv = parameters[len(parameters) // 2 :]
        
        self.set_parameters(model_weights)
        server_cv = [torch.Tensor(cv) for cv in server_cv]
        
        # Train the model
        train_scaffold(
            self.net,
            self.trainloader,
            self.device,
            self.num_epochs,
            self.learning_rate,
            self.momentum,
            self.weight_decay,
            server_cv,
            self.client_cv,
        )
        
        # Compute updates
        updated_weights = self.get_parameters(config={})
        delta_weights = [np.subtract(updated, initial) for updated, initial in zip(updated_weights, model_weights)]
        
        # Update client control variate
        cv_updates = [
            (1.0 / (self.learning_rate * self.num_epochs * len(self.trainloader))) * (updated - initial)
            for updated, initial in zip(updated_weights, model_weights)
        ]
        
        # Save updated client_cv
        self.client_cv = [
            c_i_j - c_j + cv_update
            for c_i_j, c_j, cv_update in zip(self.client_cv, server_cv, cv_updates)
        ]
        torch.save(self.client_cv, f"{self.dir}/client_cv_{self.cid}.pt")
    
        # Return weight deltas and cv updates
        return delta_weights + cv_updates, len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config: Dict[str, Scalar]):
        """Evaluate using given parameters."""
        self.set_parameters(parameters)
        loss, acc = test(self.net, self.valloader, self.device)
        return float(loss), len(self.valloader.dataset), {"accuracy": float(acc)}

# %%
def scaffold_gen_client_fn(
    trainloaders: List[DataLoader],
    valloaders: List[DataLoader],
    client_cv_dir: str,
    num_epochs: int,
    learning_rate: float,
    model: DictConfig,
    device: torch.device,
    momentum: float = 0.9,
    weight_decay: float = 0.00001,
) -> Callable[[str], FlowerClientScaffold]:  # pylint: disable=too-many-arguments
    """Generate the client function that creates the scaffold flower clients.

    Parameters
    ----------
    trainloaders: List[DataLoader]
        A list of DataLoaders, each pointing to the dataset training partition
        belonging to a particular client.
    valloaders: List[DataLoader]
        A list of DataLoaders, each pointing to the dataset validation partition
        belonging to a particular client.
    client_cv_dir : str
        The directory where the client control variates are stored (persistent storage).
    num_epochs : int
        The number of local epochs each client should run the training for before
        sending it to the server.
    learning_rate : float
        The learning rate for the SGD  optimizer of clients.
    momentum : float
        The momentum for SGD optimizer of clients.
    weight_decay : float
        The weight decay for SGD optimizer of clients.
            -------
    Callable[[str], FlowerClientScaffold]
        The client function that creates the scaffold flower clients.
    """

    def client_fn(context: Context) -> FlowerClientScaffold:
        """Create a Flower client representing a single organization."""
        # Load model
        net = CNN(model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
        
        cid = context.node_config["partition-id"]
        # Note: each client gets a different trainloader/valloader, so each client
        # will train and evaluate on their own unique data
        trainloader = trainloaders[int(cid)]
        valloader = valloaders[int(cid)]

        return FlowerClientScaffold(
            int(cid),
            net,
            trainloader,
            valloader,
            device,
            num_epochs,
            learning_rate,
            momentum,
            weight_decay,
            save_dir=client_cv_dir
        ).to_client()
    return client_fn

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">e</span>
#         <span> Implementation of FedScaffold server </span>
#     </h4>
# </div>

# %%
class ScaffoldServer(Server):
    """Implement server for SCAFFOLD."""

    def __init__(
        self,
        strategy: Strategy,
        model_cfg: DictConfig,
        client_manager: Optional[ClientManager] = None,
    ):        
        if client_manager is None:
            client_manager = SimpleClientManager()
        super().__init__(client_manager=client_manager, strategy=strategy)
        
        # Initialize server_cv to zeros
        self.model_params = CNN(model_cfg["input_dim"], model_cfg["hidden_dims"], model_cfg["num_classes"])
        model_ndarrays = [val.cpu().numpy() for val in self.model_params.state_dict().values()]
        self.parameters = ndarrays_to_parameters(model_ndarrays)
        # Initialize server_cv to zeros
        self.server_cv = [
            torch.zeros_like(torch.Tensor(param)) 
            for param in model_ndarrays
        ]

    def _get_initial_parameters(self, timeout: Optional[float], **kwargs) -> Parameters:
        parameters: Optional[Parameters] = self.strategy.initialize_parameters(
            client_manager=self._client_manager
        )
        if parameters is not None:
            log(INFO, "Using initial parameters provided by strategy")
            return parameters
        
        log(INFO, "Requesting initial parameters from one random client")
        random_client = self._client_manager.sample(1)[0]
        ins = GetParametersIns(config={})
        get_parameters_res = random_client.get_parameters(ins=ins, timeout=timeout, group_id="default_group")
        
        log(INFO, "Received initial parameters from one random client")
        # Server_cv is already initialized to zeros; no need to overwrite
        return get_parameters_res.parameters

    # pylint: disable=too-many-locals
    def fit_round(
        self,
        server_round: int,
        timeout: Optional[float],
    ) -> Optional[
        Tuple[Optional[Parameters], Dict[str, Scalar], FitResultsAndFailures]
    ]:
        """Perform a single round of federated averaging."""
        # Get clients and their respective instructions from strateg
        client_instructions = self.strategy.configure_fit(
            server_round=server_round,
            parameters=update_parameters_with_cv(self.parameters, self.server_cv),
            client_manager=self._client_manager,
        )

        if not client_instructions:
            log(INFO, "fit_round %s: no clients selected, cancel", server_round)
            return None
        log(
            DEBUG,
            "fit_round %s: strategy sampled %s clients (out of %s)",
            server_round,
            len(client_instructions),
            self._client_manager.num_available(),
        )

        # Collect `fit` results from all clients participating in this round
        results, failures = fit_clients(
            client_instructions=client_instructions,
            max_workers=self.max_workers,
            timeout=timeout,
            group_id = str(server_round)
        )
        log(
            DEBUG,
            "fit_round %s received %s results and %s failures",
            server_round,
            len(results),
            len(failures),
        )

        # Aggregate training results
        aggregated_result: Tuple[Optional[Parameters], Dict[str, Scalar]] = (
            self.strategy.aggregate_fit(server_round, results, failures)
        )
        aggregated_result_arrays_combined = []
        if aggregated_result[0] is not None:
            aggregated_result_arrays_combined = parameters_to_ndarrays(
                aggregated_result[0]
            )
        aggregated_parameters = aggregated_result_arrays_combined[
            : len(aggregated_result_arrays_combined) // 2
        ]
        aggregated_cv_update = aggregated_result_arrays_combined[
            len(aggregated_result_arrays_combined) // 2 :
        ]
        # Check if lengths match before updating server_cv
        if len(self.server_cv) != len(aggregated_cv_update):
            log(logging.ERROR, "Mismatch in lengths of server_cv and aggregated_cv_update")
            return None

        # convert server cv into ndarrays
        server_cv_np = [cv.numpy() for cv in self.server_cv]
        # update server cv
        total_clients = len(self._client_manager.all())
        cv_multiplier = len(results) / total_clients
        self.server_cv = [
            torch.from_numpy(cv + cv_multiplier * aggregated_cv_update[i])
            for i, cv in enumerate(server_cv_np)
        ]

        # update parameters x = x + 1* aggregated_update
        curr_params = parameters_to_ndarrays(self.parameters)
        updated_params = [
            x + aggregated_parameters[i] for i, x in enumerate(curr_params)
        ]
        parameters_updated = ndarrays_to_parameters(updated_params)

        # metrics
        metrics_aggregated = aggregated_result[1]
        return parameters_updated, metrics_aggregated, (results, failures)


def update_parameters_with_cv(
    parameters: Parameters, s_cv: List[torch.Tensor]
) -> Parameters:
    """Append server control variates to model parameters."""
    parameters_np = parameters_to_ndarrays(parameters)
    cv_np = [cv.numpy() for cv in s_cv]
    parameters_np.extend(cv_np)  # Now parameters include both model weights and server_cv
    return ndarrays_to_parameters(parameters_np)

# %% [markdown]
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>Implementation of FedMoon</span>
#     </h3>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">a</span>
#         <span> Implementation of CNN Model Training Adapted for FedMoon </span>
#     </h4>
# </div>

# %%
def moon_compute_accuracy(model, dataloader, device):
    """Compute accuracy."""
    was_training = False
    if model.training:
        model.eval()
        was_training = True

    true_labels_list, pred_labels_list = np.array([]), np.array([])

    correct, total = 0, 0
    if "cpu" in device.type:
        criterion = nn.CrossEntropyLoss()
    elif "cuda" in device.type:
        criterion = nn.CrossEntropyLoss().cuda()
    
    loss_collector = []
    
    with torch.no_grad():
            for _, (x, target) in enumerate(dataloader):
                #print("accuracy ", x.shape, target.shape)
                if "cuda" in device.type:
                    x, target = x.cuda(), target.to(dtype=torch.int64).cuda()
                _, _, out = model(x)
                loss = criterion(out, target)
                _, pred_label = torch.max(out.data, 1)
                loss_collector.append(loss.item())
                total += x.data.size()[0]
                correct += (pred_label == target.data).sum().item()

                if "cpu" in device.type:
                    pred_labels_list = np.append(pred_labels_list, pred_label.numpy())
                    true_labels_list = np.append(true_labels_list, target.data.numpy())
                else:
                    pred_labels_list = np.append(
                        pred_labels_list, pred_label.cpu().numpy()
                    )
                    true_labels_list = np.append(
                        true_labels_list, target.data.cpu().numpy()
                    )
            avg_loss = sum(loss_collector) / len(loss_collector)

    if was_training:
        model.train()

    return correct / float(total), avg_loss

# %%
def moon_test(net, test_dataloader, device):
    """Test function."""
    net.to(device)
    loss, test_acc = moon_compute_accuracy(net, test_dataloader, device=device)
    #print(">> Test accuracy: %f" % test_acc)
    net.to("cpu")
    return loss, test_acc

# %%
def train_moon(
    net,
    global_net,
    previous_net,
    train_dataloader,
    epochs,
    lr,
    mu,
    temperature,
    device,
):
    """Training function for MOON."""
    net.to(device)
    global_net.to(device)
    previous_net.to(device)
    train_acc, _ = moon_compute_accuracy(net, train_dataloader, device=device)
    optimizer = optim.SGD(
        filter(lambda p: p.requires_grad, net.parameters()),
        lr=lr,
        momentum=0.9,
        weight_decay=1e-5,
    )

    criterion = nn.CrossEntropyLoss() #.cuda()

    previous_net.eval()
    for param in previous_net.parameters():
        param.requires_grad = False
    #previous_net.cuda()

    cnt = 0
    cos = torch.nn.CosineSimilarity(dim=-1)

    for epoch in range(epochs):
        epoch_loss_collector = []
        epoch_loss1_collector = []
        epoch_loss2_collector = []
        for _, (x, target) in enumerate(train_dataloader):
            # print("training ", x.shape, target.shape)
            x, target = x.to(device), target.to(device)

            optimizer.zero_grad()
            x.requires_grad = False
            target.requires_grad = False
            target = target.long()

            # pro1 is the representation by the current model (Line 14 of Algorithm 1)
            _, pro1, out = net(x)
            # pro2 is the representation by the global model (Line 15 of Algorithm 1)
            _, pro2, _ = global_net(x)
            # posi is the positive pair
            posi = cos(pro1, pro2)
            logits = posi.reshape(-1, 1)

            previous_net.to(device)
            # pro 3 is the representation by the previous model (Line 16 of Algorithm 1)
            _, pro3, _ = previous_net(x)
            # nega is the negative pair
            nega = cos(pro1, pro3)
            logits = torch.cat((logits, nega.reshape(-1, 1)), dim=1)

            previous_net.to(device)
            logits /= temperature
            labels = torch.zeros(x.size(0)).long()#.cuda().long()
            # compute the model-contrastive loss (Line 17 of Algorithm 1)
            loss2 = mu * criterion(logits, labels)
            # compute the cross-entropy loss (Line 13 of Algorithm 1)
            loss1 = criterion(out, target)
            # compute the loss (Line 18 of Algorithm 1)
            loss = loss1 + loss2

            loss.backward()
            optimizer.step()

            cnt += 1
            epoch_loss_collector.append(loss.item())
            epoch_loss1_collector.append(loss1.item())
            epoch_loss2_collector.append(loss2.item())

        epoch_loss = sum(epoch_loss_collector) / len(epoch_loss_collector)
        epoch_loss1 = sum(epoch_loss1_collector) / len(epoch_loss1_collector)
        epoch_loss2 = sum(epoch_loss2_collector) / len(epoch_loss2_collector)
        # print(
        #     "Epoch: %d Loss: %f Loss1: %f Loss2: %f"
        #     % (epoch, epoch_loss, epoch_loss1, epoch_loss2)
        # )

    previous_net.to(device)
    train_acc, _ = moon_compute_accuracy(net, train_dataloader, device=device)

    # print(">> Training accuracy: %f" % train_acc)
    net.to(device)
    global_net.to(device)
    # print(" ** Training complete **")
    return net

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">b</span>
#         <span> Implementation of FedMoon Flower client </span>
#     </h4>
# </div>

# %%
class FlowerClientMoon(fl.client.NumPyClient):
    """Standard Flower client for CNN training."""

    def __init__(
        self,
        net_id: int,
        n_classes: int,
        input_dim:int,
        hidden_dims: List[int],
        output_dim: int,
        trainloader: DataLoader,
        valloader: DataLoader,
        device: torch.device,
        num_epochs: int,
        learning_rate: float,
        mu: float,
        temperature: float,
        model_dir: str,
       
    ):  # pylint: disable=too-many-arguments
        self.net = init_net(input_dim =input_dim ,hidden_dims = hidden_dims, output_dim = output_dim, n_classes=n_classes, device=device)
        self.net_id = net_id
        self.n_classes = n_classes
        self.input_dim = input_dim
        self.hidden_dims = hidden_dims
        self.output_dim = output_dim
        self.trainloader = trainloader
        self.valloader = valloader
        self.device = device
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.mu = mu  # pylint: disable=invalid-name
        self.temperature = temperature
        self.model_dir = model_dir

    def get_parameters(self, config: Dict[str, Scalar]) -> NDArrays:
        """Return the parameters of the current net."""
        return [val.cpu().numpy() for _, val in self.net.state_dict().items()]

    def set_parameters(self, parameters: NDArrays) -> None:
        """Change the parameters of the model using the given ones."""
        params_dict = zip(self.net.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.from_numpy(v) for k, v in params_dict})
        self.net.load_state_dict(state_dict, strict=True)

    def fit(
        self, parameters: NDArrays, config: Dict[str, Scalar]
    ) -> Tuple[NDArrays, int, Dict]:
        """Implement distributed fit function for a given client."""
        self.set_parameters(parameters)
        prev_net = init_net(input_dim =self.input_dim ,hidden_dims = self.hidden_dims, output_dim = self.output_dim, n_classes=self.n_classes, device=self.device)
        if not os.path.exists(os.path.join(self.model_dir, str(self.net_id))):
            prev_net = copy.deepcopy(self.net)
        else:
            # load previous model from model_dir
            prev_net.load_state_dict(
                torch.load(
                    os.path.join(self.model_dir, str(self.net_id), "prev_net.pt"),
                     weights_only=True
                )
            )
        global_net = init_net(input_dim =self.input_dim ,hidden_dims = self.hidden_dims, output_dim = self.output_dim, n_classes=self.n_classes, device=self.device)
        global_net.load_state_dict(self.net.state_dict())

        train_moon(
                self.net,
                global_net,
                prev_net,
                self.trainloader,
                self.num_epochs,
                self.learning_rate,
                self.mu,
                self.temperature,
                self.device,
            )
        if not os.path.exists(os.path.join(self.model_dir, str(self.net_id))):
            os.makedirs(os.path.join(self.model_dir, str(self.net_id)))
        torch.save(
            self.net.state_dict(),
            os.path.join(self.model_dir, str(self.net_id), "prev_net.pt"),
        )
        return self.get_parameters({}), len(self.trainloader), {"is_straggler": False}

    def evaluate(
        self, parameters: NDArrays, config: Dict[str, Scalar]
    ) -> Tuple[float, int, Dict]:
        """Implement distributed evaluation for a given client."""
        self.set_parameters(parameters)
        # skip evaluation in the client-side
        loss = 0.0
        accuracy = 0.0
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %%
def moon_gen_client_fn(
    trainloaders: List[DataLoader],
    testloaders: List[DataLoader],
    device: torch.device,
    cfg: DictConfig,
    num_epochs: int,
    learning_rate: float,
    mu: float,
    temperature: float,
    model_dir: str,
) -> Callable[[str], FlowerClientMoon]:
    """Generate the client function that creates the Flower Clients."""

    def client_fn(context: Context) -> FlowerClientMoon:
        """Create a Flower client representing a single organization."""
        cid =  context.node_config["partition-id"]
        trainloader = trainloaders[int(cid)]
        testloader = testloaders[int(cid)]

        return FlowerClientMoon(
            int(cid),
            cfg['num_classes'],
            cfg['input_dim'],
            cfg['hidden_dims'],
            cfg['output_dim'],
            trainloader,
            testloader,
            device,
            num_epochs,
            learning_rate,
            mu,
            temperature,
            model_dir,
        ).to_client()

    return client_fn

# %% [markdown]
# <div style="border-left: 4px solid #3498db; border-radius: 0 10px 10px 0; padding: 12px; margin: 15px 0 15px 90px; box-shadow: 2px 2px 8px rgba(0,0,0,0.08); background: linear-gradient(to right, #F8FBFD, #F5F8FA);">
#     <h4 style="font-size: 18px; font-weight: bold; color: #3A6073; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 1px 6px; border-radius: 6px; margin-right: 10px; font-size: 15px; box-shadow: 1px 1px 3px rgba(0,0,0,0.1);">c</span>
#         <span> Implementation of the Centralized Evaluation Function </span>
#     </h4>
# </div>

# %%
def moon_gen_evaluate_fn(
    testloader: DataLoader,
    device: torch.device,
    cfg: DictConfig,
) -> Callable[
    [int, NDArrays, Dict[str, Scalar]], Optional[Tuple[float, Dict[str, Scalar]]]
]:
    """Generate the function for centralized evaluation."""

    def evaluate(
        server_round: int, parameters_ndarrays: NDArrays, config: Dict[str, Scalar]
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        # pylint: disable=unused-argument
        net = init_net(input_dim =cfg['input_dim'] ,hidden_dims = cfg['hidden_dims'], output_dim = cfg['output_dim'], n_classes=cfg['num_classes'], device=device)
        params_dict = zip(net.state_dict().keys(), parameters_ndarrays)
        state_dict = OrderedDict({k: torch.from_numpy(v) for k, v in params_dict})
        net.load_state_dict(state_dict, strict=True)
        net.to(device)

        accuracy, loss = moon_test(net, testloader, device=device)
        return loss, {"test_accuracy": accuracy}

    return evaluate

# %% [markdown]
# <a id='4'></a>
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 30px; margin: 30px 0; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to right, #2C3E50, #4CA1AF);">
#     <h1 style="font-size: 34px; font-weight: bold; color: white; text-align: center; font-family: 'Arial'; margin: 0; display: flex; align-items: center; justify-content: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 5px 15px; border-radius: 15px; margin-right: 15px; box-shadow: 3px 3px 10px rgba(0,0,0,0.2);">IV</span>
#         <span>Simulation</span>
#     </h1>
# </div>

# %%
NUM_CLIENTS= 10 
BATCH_SIZE = 64
LEARNING_RATE = 0.01
NUM_EPOCHS = 10
NUM_ROUNDS = 10
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# <a id='41'></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">1</span>
#         <span>Distribution-based label imbalance: Partitioning  with Dirichlet distribution and $\beta=0.5$</span>
#     </h2>
# </div>

# %%
BETA = 0.5 # Dirichlet distribution
data_config = DictConfig({"name": "mnist", "partitioning": "dirichlet", "alpha": BETA, "batch_size": BATCH_SIZE})

# %%
federated_dataset = FederatedDataset(data_config, num_clients=NUM_CLIENTS)
trainloaders, valloaders, testloader = federated_dataset.get_dataloaders()
dataset_stats = DatasetStatistics(federated_dataset)
# Display statistics
dataset_stats.plot_statistics()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 59.0MB/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.74MB/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.0MB/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.02MB/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">A</span>
#         <span>FedAvg</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_avg_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_avg_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_avg_strategy = FedAvg(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_avg_evaluate_fn,
    )
fed_avg_server = Server(strategy=fed_avg_strategy, client_manager=SimpleClientManager())

# %%
fedavg_history = fl.simulation.start_simulation(
        server=fed_avg_server,
        client_fn=fed_avg_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_avg_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 14:44:56,791	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18689020724.0, 'node:172.19.2.2': 1.0, 'object_store_memory': 9344510361.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=331) 2025-03-21 14:45:01.085519: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=331) 2025-03-21 14:45:01.128887: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=331) 2025-03-21 14:45:01.141621: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.304052734375, {'test_accuracy': 0.1009}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.23531298828125, {'test_accuracy': 0.5546}, 78.87501555300003)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 0.593280712890625, {'test_accuracy': 0.8276}, 155.26668526499998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.434158447265625, {'test_accuracy': 0.8762}, 232.49073306599996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.3903943603515625, {'test_accuracy': 0.8939}, 308.23829243499995)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.2773739501953125, {'test_accuracy': 0.9249}, 389.438905307)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.2138427490234375, {'test_accuracy': 0.9411}, 470.1711381429999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.13904228515625, {'test_accuracy': 0.963}, 546.3250458660001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.11617835693359375, {'test_accuracy': 0.9708}, 626.884865203)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.0979200927734375, {'test_accuracy': 0.975}, 711.148249039)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.08141854858398437, {'test_accuracy': 0.9783}, 786.0750354190001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 787.76s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.2454905104366758
# INFO :      		round 2: 0.5669044777663987
# INFO :      		round 3: 0.4162255624502405
# INFO :      		round 4: 0.38834803899520387
# INFO :      		round 5: 0.2904594777216169
# INFO :      		round 6: 0.2330030506189061
# INFO :      		round 7: 0.15635647093468694
# INFO :      		round 8: 0.13421351990917227
# INFO :      		round 9: 0.11277045182540289
# INFO :      		round 10: 0.09499497813151533
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.304052734375
# INFO :      		round 1: 1.23531298828125
# INFO :      		round 2: 0.593280712890625
# INFO :      		round 3: 0.434158447265625
# INFO :      		round 4: 0.3903943603515625
# INFO :      		round 5: 0.2773739501953125
# INFO :      		round 6: 0.2138427490234375
# INFO :      		round 7: 0.13904228515625
# INFO :      		round 8: 0.11617835693359375
# INFO :      		round 9: 0.0979200927734375
# INFO :      		round 10: 0.08141854858398437
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1009),
# INFO :      	                   (1, 0.5546),
# INFO :      	                   (2, 0.8276),
# INFO :      	                   (3, 0.8762),
# INFO :      	                   (4, 0.8939),
# INFO :      	                   (5, 0.9249),
# INFO :      	                   (6, 0.9411),
# INFO :      	                   (7, 0.963),
# INFO :      	                   (8, 0.9708),
# INFO :      	                   (9, 0.975),
# INFO :      	                   (10, 0.9783)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">B</span>
#         <span>FedProx</span>
#     </h3>
# </div>

# %%
PROXIMAL_MU = 0.1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_prox_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_prox_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_prox_strategy = FedProx(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_prox_evaluate_fn,
        proximal_mu = PROXIMAL_MU
    )
fed_prox_server = Server(strategy=fed_prox_strategy, client_manager=SimpleClientManager())

# %%
fedprox_history = fl.simulation.start_simulation(
        server=fed_prox_server,
        client_fn=fed_prox_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_prox_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 14:58:24,392	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'memory': 18615356622.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9307678310.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=981) 2025-03-21 14:58:28.382514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=981) 2025-03-21 14:58:28.425228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=981) 2025-03-21 14:58:28.437370: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3029853515625, {'test_accuracy': 0.0974}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.95361357421875, {'test_accuracy': 0.7463}, 77.39206374900004)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 0.47789755859375, {'test_accuracy': 0.8439}, 154.7334382240001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.3412294921875, {'test_accuracy': 0.8935}, 232.4692320370002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.2117321533203125, {'test_accuracy': 0.9349}, 314.9210277020002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.193155078125, {'test_accuracy': 0.9448}, 391.3583323060002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.11085799560546875, {'test_accuracy': 0.9712}, 467.44311314900006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.09366641235351562, {'test_accuracy': 0.9762}, 542.8829553520002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.08403538818359375, {'test_accuracy': 0.9786}, 618.4865611050002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.07229761352539063, {'test_accuracy': 0.9807}, 696.096996024)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.06477760009765625, {'test_accuracy': 0.9818}, 774.6936625920002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 776.57s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.958578511028786
# INFO :      		round 2: 0.4611179318634409
# INFO :      		round 3: 0.33283265233595916
# INFO :      		round 4: 0.2200076726030596
# INFO :      		round 5: 0.19868518559667087
# INFO :      		round 6: 0.12579453001733096
# INFO :      		round 7: 0.10862364834022296
# INFO :      		round 8: 0.09688470574921237
# INFO :      		round 9: 0.0852706752551308
# INFO :      		round 10: 0.08249349405013344
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3029853515625
# INFO :      		round 1: 0.95361357421875
# INFO :      		round 2: 0.47789755859375
# INFO :      		round 3: 0.3412294921875
# INFO :      		round 4: 0.2117321533203125
# INFO :      		round 5: 0.193155078125
# INFO :      		round 6: 0.11085799560546875
# INFO :      		round 7: 0.09366641235351562
# INFO :      		round 8: 0.08403538818359375
# INFO :      		round 9: 0.07229761352539063
# INFO :      		round 10: 0.06477760009765625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0974),
# INFO :      	                   (1, 0.7463),
# INFO :      	                   (2, 0.8439),
# INFO :      	                   (3, 0.8935),
# INFO :      	                   (4, 0.9349),
# INFO :      	                   (5, 0.9448),
# INFO :      	                   (6, 0.9712),
# INFO :      	                   (7, 0.9762),
# INFO :      	                   (8, 0.9786),
# INFO :      	                   (9, 0.9807),
# INFO :      	                   (10, 0.9818)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>FedAdam</span>
#     </h3>
# </div>

# %%
BETA_1=0.9 
BETA_2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adam_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adam_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adam_strategy = FedAdam(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adam_evaluate_fn,
        initial_parameters = initial_parameters,
        beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_adam_server = Server(strategy=fed_adam_strategy, client_manager=SimpleClientManager())

# %%
fedadam_history = fl.simulation.start_simulation(
        server=fed_adam_server,
        client_fn=fed_adam_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adam_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 15:11:39,709	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9306447052.0, 'memory': 18612894107.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3050611328125, {'test_accuracy': 0.1028}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (pid=1627) 2025-03-21 15:11:45.450580: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=1627) 2025-03-21 15:11:45.503412: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=1627) 2025-03-21 15:11:45.515998: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 10.50358671875, {'test_accuracy': 0.4898}, 90.59718758899999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 5.1082625, {'test_accuracy': 0.769}, 167.72892960599984)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.4694794921875, {'test_accuracy': 0.81}, 249.0346837689999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.87114677734375, {'test_accuracy': 0.9154}, 339.777927957)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.680975634765625, {'test_accuracy': 0.955}, 435.0365244899999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.60117060546875, {'test_accuracy': 0.9611}, 532.7513690999999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.7556109375, {'test_accuracy': 0.9562}, 622.4713222749997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.554210546875, {'test_accuracy': 0.9715}, 716.2012640969997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.5634681640625, {'test_accuracy': 0.9754}, 806.6370566169999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.7120263671875, {'test_accuracy': 0.9705}, 894.2783900709996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 896.04s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 10.275830737585382
# INFO :      		round 2: 4.825070799474316
# INFO :      		round 3: 2.687431514422205
# INFO :      		round 4: 0.9482911409073268
# INFO :      		round 5: 0.76170741570538
# INFO :      		round 6: 0.7909678759617501
# INFO :      		round 7: 0.8987602602457926
# INFO :      		round 8: 0.719283312962155
# INFO :      		round 9: 0.7682428391108183
# INFO :      		round 10: 0.9475592276456223
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3050611328125
# INFO :      		round 1: 10.50358671875
# INFO :      		round 2: 5.1082625
# INFO :      		round 3: 2.4694794921875
# INFO :      		round 4: 0.87114677734375
# INFO :      		round 5: 0.680975634765625
# INFO :      		round 6: 0.60117060546875
# INFO :      		round 7: 0.7556109375
# INFO :      		round 8: 0.554210546875
# INFO :      		round 9: 0.5634681640625
# INFO :      		round 10: 0.7120263671875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1028),
# INFO :      	                   (1, 0.4898),
# INFO :      	                   (2, 0.769),
# INFO :      	                   (3, 0.81),
# INFO :      	                   (4, 0.9154),
# INFO :      	                   (5, 0.955),
# INFO :      	                   (6, 0.9611),
# INFO :      	                   (7, 0.9562),
# INFO :      	                   (8, 0.9715),
# INFO :      	                   (9, 0.9754),
# INFO :      	                   (10, 0.9705)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">D</span>
#         <span>FedAdagrad</span>
#     </h3>
# </div>

# %%
TAU  = 0.2
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adagrad_strategy = FedAdagrad(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
    tau=TAU
    )
fed_adagrad_server = Server(strategy=fed_adagrad_strategy, client_manager=SimpleClientManager())

# %%
fedadagrad_history = fl.simulation.start_simulation(
        server=fed_adagrad_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adagrad_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 15:26:45,988	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18610269390.0, 'object_store_memory': 9305134694.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=2288) 2025-03-21 15:26:50.863761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2288) 2025-03-21 15:26:50.909637: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2288) 2025-03-21 15:26:50.922328: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.303678125, {'test_accuracy': 0.0974}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.159151171875, {'test_accuracy': 0.4751}, 91.44001233200015)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 1.4934765625, {'test_accuracy': 0.6748}, 172.16255490100002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.806994482421875, {'test_accuracy': 0.7808}, 250.07117568900003)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.510426904296875, {'test_accuracy': 0.8237}, 329.97846348300027)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.41727783203125, {'test_accuracy': 0.8437}, 406.6332973819999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.398226806640625, {'test_accuracy': 0.8564}, 487.2099665280002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.3419964599609375, {'test_accuracy': 0.8727}, 568.025190115)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.3184177734375, {'test_accuracy': 0.8813}, 647.258626623)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.278784619140625, {'test_accuracy': 0.8983}, 723.9735038499998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.2474110107421875, {'test_accuracy': 0.9115}, 801.4264022880002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 803.19s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.158105130669592
# INFO :      		round 2: 1.496054574598703
# INFO :      		round 3: 0.8147124021032638
# INFO :      		round 4: 0.5091133676543882
# INFO :      		round 5: 0.40952294183182986
# INFO :      		round 6: 0.38925589886484663
# INFO :      		round 7: 0.33990865395161474
# INFO :      		round 8: 0.3226323897699969
# INFO :      		round 9: 0.28709781352738745
# INFO :      		round 10: 0.2590883483239956
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.303678125
# INFO :      		round 1: 2.159151171875
# INFO :      		round 2: 1.4934765625
# INFO :      		round 3: 0.806994482421875
# INFO :      		round 4: 0.510426904296875
# INFO :      		round 5: 0.41727783203125
# INFO :      		round 6: 0.398226806640625
# INFO :      		round 7: 0.3419964599609375
# INFO :      		round 8: 0.3184177734375
# INFO :      		round 9: 0.278784619140625
# INFO :      		round 10: 0.2474110107421875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0974),
# INFO :      	                   (1, 0.4751),
# INFO :      	                   (2, 0.6748),
# INFO :      	                   (3, 0.7808),
# INFO :      	                   (4, 0.8237),
# INFO :      	                   (5, 0.8437),
# INFO :      	                   (6, 0.8564),
# INFO :      	                   (7, 0.8727),
# INFO :      	                   (8, 0.8813),
# INFO :      	                   (9, 0.8983),
# INFO :      	                   (10, 0.9115)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">E</span>
#         <span>FedYogi</span>
#     </h3>
# </div>

# %%
BETA1= 0.9
BETA2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_yogi_strategy = FedYogi(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
     beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_yogi_server = Server(strategy=fed_yogi_strategy, client_manager=SimpleClientManager())

# %%
fedyogi_history = fl.simulation.start_simulation(
        server=fed_yogi_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_yogi_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 15:40:19,073	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'object_store_memory': 9304580505.0, 'node:__internal_head__': 1.0, 'CPU': 4.0, 'memory': 18609161012.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=2935) 2025-03-21 15:40:24.130679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.3031283203125, {'test_accuracy': 0.0963}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (pid=2935) 2025-03-21 15:40:24.204807: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2935) 2025-03-21 15:40:24.224615: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2650361328125, {'test_accuracy': 0.2418}, 84.64063095600022)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.03004609375, {'test_accuracy': 0.7031}, 162.6955103790001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.312791796875, {'test_accuracy': 0.7159}, 241.23840078500007)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.9612060546875, {'test_accuracy': 0.7144}, 329.91555521800046)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.51845546875, {'test_accuracy': 0.7379}, 409.57808594800053)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.248485546875, {'test_accuracy': 0.7709}, 488.4170575610001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.62781796875, {'test_accuracy': 0.8061}, 565.9304744080005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.4686345703125, {'test_accuracy': 0.836}, 642.5873938259997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 1.9928818359375, {'test_accuracy': 0.8591}, 720.2884531940003)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 1.476815625, {'test_accuracy': 0.8766}, 801.662503006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 803.42s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.2668114681892826
# INFO :      		round 2: 2.0367926813269395
# INFO :      		round 3: 1.3288274501624944
# INFO :      		round 4: 0.9425523457644859
# INFO :      		round 5: 1.435723905735528
# INFO :      		round 6: 2.0943990741452594
# INFO :      		round 7: 2.4340363795486417
# INFO :      		round 8: 2.291177960139213
# INFO :      		round 9: 1.8860298519558936
# INFO :      		round 10: 1.4457168181891946
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3031283203125
# INFO :      		round 1: 2.2650361328125
# INFO :      		round 2: 2.03004609375
# INFO :      		round 3: 1.312791796875
# INFO :      		round 4: 0.9612060546875
# INFO :      		round 5: 1.51845546875
# INFO :      		round 6: 2.248485546875
# INFO :      		round 7: 2.62781796875
# INFO :      		round 8: 2.4686345703125
# INFO :      		round 9: 1.9928818359375
# INFO :      		round 10: 1.476815625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0963),
# INFO :      	                   (1, 0.2418),
# INFO :      	                   (2, 0.7031),
# INFO :      	                   (3, 0.7159),
# INFO :      	                   (4, 0.7144),
# INFO :      	                   (5, 0.7379),
# INFO :      	                   (6, 0.7709),
# INFO :      	                   (7, 0.8061),
# INFO :      	                   (8, 0.836),
# INFO :      	                   (9, 0.8591),
# INFO :      	                   (10, 0.8766)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">F</span>
#         <span>FedNova</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_nova_client_fn = nova_gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS, LEARNING_RATE)
fed_nova_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_nova_strategy =FedNovaStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_nova_evaluate_fn,
)

fed_nova_server = FedNovaServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_nova_strategy,
    )

# %%
fednova_history = fl.simulation.start_simulation(
        server=fed_nova_server,
        client_fn=fed_nova_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_nova_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 15:53:52,325	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9304192204.0, 'memory': 18608384411.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=3573) 2025-03-21 15:53:56.663427: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=3573) 2025-03-21 15:53:56.710136: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=3573) 2025-03-21 15:53:56.723879: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.303740625, {'test_accuracy': 0.101}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.772053955078125, {'test_accuracy': 0.777}, 75.97609977199954)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 0.2383923828125, {'test_accuracy': 0.9173}, 149.64572888699968)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 0.1149681884765625, {'test_accuracy': 0.9635}, 226.73016280799948)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 0.08666844482421875, {'test_accuracy': 0.9736}, 298.8803170840001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 0.0762343505859375, {'test_accuracy': 0.9769}, 373.7180287199999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 0.0709507080078125, {'test_accuracy': 0.9801}, 453.3280269520001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 0.06326121826171875, {'test_accuracy': 0.9823}, 530.0130324989996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 0.05846669311523438, {'test_accuracy': 0.9834}, 611.8177930229995)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 0.05967913818359375, {'test_accuracy': 0.9834}, 694.3473550709996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 0.05721704711914063, {'test_accuracy': 0.984}, 769.4407478899993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 771.26s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.7666890255366269
# INFO :      		round 2: 0.23894403847412835
# INFO :      		round 3: 0.13005061333301943
# INFO :      		round 4: 0.10823366519224005
# INFO :      		round 5: 0.09898490045767022
# INFO :      		round 6: 0.09507271492754509
# INFO :      		round 7: 0.08746718731223437
# INFO :      		round 8: 0.0836816381249068
# INFO :      		round 9: 0.08483411168348055
# INFO :      		round 10: 0.08239475985149604
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.303740625
# INFO :      		round 1: 0.772053955078125
# INFO :      		round 2: 0.2383923828125
# INFO :      		round 3: 0.1149681884765625
# INFO :      		round 4: 0.08666844482421875
# INFO :      		round 5: 0.0762343505859375
# INFO :      		round 6: 0.0709507080078125
# INFO :      		round 7: 0.06326121826171875
# INFO :      		round 8: 0.05846669311523438
# INFO :      		round 9: 0.05967913818359375
# INFO :      		round 10: 0.05721704711914063
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.101),
# INFO :      	                   (1, 0.777),
# INFO :      	                   (2, 0.9173),
# INFO :      	                   (3, 0.9635),
# INFO :      	                   (4, 0.9736),
# INFO :      	                   (5, 0.9769),
# INFO :      	                   (6, 0.9801),
# INFO :      	                   (7, 0.9823),
# INFO :      	                   (8, 0.9834),
# INFO :      	                   (9, 0.9834),
# INFO :      	                   (10, 0.984)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">G</span>
#         <span>FedScaffold</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
client_cv_dir = os.path.join("/kaggle/working/", "client_cvs")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_scaffold_client_fn =scaffold_gen_client_fn( trainloaders, valloaders,client_cv_dir,NUM_EPOCHS, LEARNING_RATE, model_cfg,device)
fed_scaffold_evaluate_fn = gen_evaluate_fn(testloader, 
                              device,model_cfg)

# %%
fed_scaffold_strategy =ScaffoldStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_scaffold_evaluate_fn,
)

fed_scaffold_server = ScaffoldServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_scaffold_strategy,
    model_cfg=model_cfg,
    )

# %%
fedscaffold_history = fl.simulation.start_simulation(
        server=fed_scaffold_server,
        client_fn=fed_scaffold_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_scaffold_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 16:07:03,309	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9302849126.0, 'memory': 18605698254.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=4234) 2025-03-21 16:07:07.489642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=4234) 2025-03-21 16:07:07.539588: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=4234) 2025-03-21 16:07:07.560750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.302427734375, {'test_accuracy': 0.1033}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.09001181640625, {'test_accuracy': 0.6765}, 83.80661570800021)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 0.710840625, {'test_accuracy': 0.7536}, 161.017760791)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 0.756161376953125, {'test_accuracy': 0.7449}, 238.0289019259999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 0.767715478515625, {'test_accuracy': 0.7486}, 320.1084832099996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 0.80008623046875, {'test_accuracy': 0.7268}, 395.91399687899957)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 0.7720494140625, {'test_accuracy': 0.7252}, 478.3020517320001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 0.82975703125, {'test_accuracy': 0.7121}, 553.6435125759999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 0.86091025390625, {'test_accuracy': 0.7013}, 628.7096427159995)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 0.8762611328125, {'test_accuracy': 0.6993}, 713.8382632519997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 0.8329486328125, {'test_accuracy': 0.7127}, 790.3721762349996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 792.21s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.0942792057434347
# INFO :      		round 2: 0.7084391709563731
# INFO :      		round 3: 0.7482090559579914
# INFO :      		round 4: 0.7556863856403091
# INFO :      		round 5: 0.7902567836942476
# INFO :      		round 6: 0.7627456456800553
# INFO :      		round 7: 0.8178253889759832
# INFO :      		round 8: 0.8506684431717982
# INFO :      		round 9: 0.8656512033032766
# INFO :      		round 10: 0.8220201468093941
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.302427734375
# INFO :      		round 1: 1.09001181640625
# INFO :      		round 2: 0.710840625
# INFO :      		round 3: 0.756161376953125
# INFO :      		round 4: 0.767715478515625
# INFO :      		round 5: 0.80008623046875
# INFO :      		round 6: 0.7720494140625
# INFO :      		round 7: 0.82975703125
# INFO :      		round 8: 0.86091025390625
# INFO :      		round 9: 0.8762611328125
# INFO :      		round 10: 0.8329486328125
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1033),
# INFO :      	                   (1, 0.6765),
# INFO :      	                   (2, 0.7536),
# INFO :      	                   (3, 0.7449),
# INFO :      	                   (4, 0.7486),
# INFO :      	                   (5, 0.7268),
# INFO :      	                   (6, 0.7252),
# INFO :      	                   (7, 0.7121),
# INFO :      	                   (8, 0.7013),
# INFO :      	                   (9, 0.6993),
# INFO :      	                   (10, 0.7127)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">H</span>
#         <span>FedMoon</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "output_dim": 256,
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
MU = 5
TEMPERATURE = 0.5
MODEL_DIR = os.path.join("/kaggle/working/", "models")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_moon_client_fn =moon_gen_client_fn( trainloaders, valloaders,device,model_cfg,NUM_EPOCHS,
                                       LEARNING_RATE, MU,TEMPERATURE,MODEL_DIR)
fed_moon_evaluate_fn = moon_gen_evaluate_fn(testloader, 
                             device,model_cfg)

# %%
fed_moon_strategy =fl.server.strategy.FedAvg(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_moon_evaluate_fn,
)

# %%
fedmoon_history = fl.simulation.start_simulation(
        client_fn=fed_moon_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_moon_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 16:20:34,830	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'memory': 18603805902.0, 'object_store_memory': 9301902950.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=4882) 2025-03-21 16:20:38.816959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=4880) 2025-03-21 16:20:38.901149: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=4880) 2025-03-21 16:20:38.913528: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3037540912628174, {'test_accuracy': 0.0958}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.3278422355651855, {'test_accuracy': 0.5645}, 150.83553722499983)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 0.5197608470916748, {'test_accuracy': 0.8242}, 304.657267562)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.20714659988880157, {'test_accuracy': 0.9258}, 452.35043259600025)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.10254239290952682, {'test_accuracy': 0.9682}, 597.7703173660002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.08435395359992981, {'test_accuracy': 0.9734}, 737.5362698320005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.06429581344127655, {'test_accuracy': 0.9799}, 892.866439546)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.0592380054295063, {'test_accuracy': 0.9807}, 1034.370704242)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.05190932750701904, {'test_accuracy': 0.983}, 1176.166198551)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.05182734876871109, {'test_accuracy': 0.9833}, 1316.955811109)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.04794086143374443, {'test_accuracy': 0.9845}, 1459.7231401919998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 1461.30s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3037540912628174
# INFO :      		round 1: 1.3278422355651855
# INFO :      		round 2: 0.5197608470916748
# INFO :      		round 3: 0.20714659988880157
# INFO :      		round 4: 0.10254239290952682
# INFO :      		round 5: 0.08435395359992981
# INFO :      		round 6: 0.06429581344127655
# INFO :      		round 7: 0.0592380054295063
# INFO :      		round 8: 0.05190932750701904
# INFO :      		round 9: 0.05182734876871109
# INFO :      		round 10: 0.04794086143374443
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0958),
# INFO :      	                   (1, 0.5645),
# INFO :      	                   (2, 0.8242),
# INFO :      	                   (3, 0.9258),
# INFO :      	                   (4, 0.9682),
# INFO :      	                   (5, 0.9734),
# INFO :      	                   (6, 0.9799),
# INFO :      	                   (7, 0.9807),
# INFO :      	                   (8, 0.983),
# INFO :      	                   (9, 0.9833),
# INFO :      	                   (10, 0.9845)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">L</span>
#         <span>Learning Curve: Test Accuracy vs. Communication Rounds</span>
#     </h3>
# </div>

# %%
def extract_data(history):
    centralized_metrics = history.metrics_centralized
    rounds = [round_num for round_num, _ in centralized_metrics["test_accuracy"]]
    accuracies = [value for _, value in centralized_metrics["test_accuracy"]]
    return rounds, accuracies
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def plot_federated_learning_curves(
    fedavg_history,
    fedprox_history,
    fedadam_history,
    fedadagrad_history,
    fedyogi_history,
    fednova_history,
    fedscaffold_history,
    fedmoon_history,
    save_plot=False,
    filename='federated_learning_plot.png'
):
    # Extract data
    fedavg_rounds, fedavg_accuracies = extract_data(fedavg_history)
    fedprox_rounds, fedprox_accuracies = extract_data(fedprox_history)
    fedadam_rounds, fedadam_accuracies = extract_data(fedadam_history)
    fedadagrad_rounds, fedadagrad_accuracies = extract_data(fedadagrad_history)
    fedyogi_rounds, fedyogi_accuracies = extract_data(fedyogi_history)
    fednova_rounds, fednova_accuracies = extract_data(fednova_history)
    fedscaffold_rounds, fedscaffold_accuracies = extract_data(fedscaffold_history)
    fedmoon_rounds, fedmoon_accuracies = extract_data(fedmoon_history)

    # Plotting
    plt.figure(figsize=(8, 6), dpi=150)

    plt.plot(fedavg_rounds, fedavg_accuracies, label='FedAvg', color='#1f77b4', linestyle='-',marker='^', markersize=6)
    plt.plot(fedprox_rounds, fedprox_accuracies, label='FedProx, μ=0.1', color='#ff7f0e', linestyle='--',marker='*',markersize=6)
    plt.plot(fedadam_rounds, fedadam_accuracies, label='Adam', color='#2ca02c', linestyle=':',marker='o',markersize=6)
    plt.plot(fedadagrad_rounds, fedadagrad_accuracies, label='FedAdagrad', color='#d62728', linestyle='-.',marker='s',markersize=6)
    plt.plot(fedyogi_rounds, fedyogi_accuracies, label='FedYogi', color='#9467bd', linestyle=(0, (3, 1, 1, 1)),marker='D',markersize=6)
    plt.plot(fednova_rounds, fednova_accuracies, label='FedNova', color='#8c564b', linestyle=(0, (5, 1)),marker='P',markersize=6)
    plt.plot(fedscaffold_rounds, fedscaffold_accuracies, label='FedScaffold', color='#e377c2', linestyle=(0, (1, 1)),marker='X',markersize=6)
    plt.plot(fedmoon_rounds, fedmoon_accuracies, label='FedMoon', color='#7f7f7f', linestyle=(0, (3, 5, 1, 5)),marker='H',markersize=6)

    # Labels and title
    plt.xlabel('Communication round', fontsize=20)
    plt.ylabel('Test acc', fontsize=20)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)

    # Legend
    plt.legend(loc='lower right', fontsize=18)

    plt.tight_layout()

    # Save plot (optional)
    if save_plot:
        plt.savefig(filename)  # Saves the plot to a file

    # Show plot
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %%
plot_federated_learning_curves(
    fedavg_history,
    fedprox_history,
    fedadam_history,
    fedadagrad_history,
    fedyogi_history,
    fednova_history,
    fedscaffold_history,
    fedmoon_history,
    save_plot=True,
    filename='label Skew beta 0_5.png'
)

# %% [markdown]
# <a id='42'></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">2</span>
#         <span>Quantity-based label imbalance: Partitioning  with log-normal probability distribution and $C=1$</span>
#     </h2>
# </div>

# %%
C = 1
data_config = DictConfig({"name": "mnist", "partitioning": "label_quantity", "labels_per_client": C, "batch_size": BATCH_SIZE})

# %%
federated_dataset = FederatedDataset(data_config, num_clients=NUM_CLIENTS)
trainloaders, valloaders, testloader = federated_dataset.get_dataloaders()
dataset_stats = DatasetStatistics(federated_dataset)
# Display statistics
dataset_stats.plot_statistics()

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">A</span>
#         <span>FedAvg</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_avg_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_avg_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_avg_strategy = FedAvg(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_avg_evaluate_fn,
    )
fed_avg_server = Server(strategy=fed_avg_strategy, client_manager=SimpleClientManager())

# %%
fedavg_history = fl.simulation.start_simulation(
        server=fed_avg_server,
        client_fn=fed_avg_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_avg_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 16:45:28,689	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18567180288.0, 'object_store_memory': 9283590144.0, 'node:__internal_head__': 1.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=5595) 2025-03-21 16:45:32.435135: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=5595) 2025-03-21 16:45:32.475690: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=5595) 2025-03-21 16:45:32.488582: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3040326171875, {'test_accuracy': 0.0974}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 3.283187890625, {'test_accuracy': 0.1135}, 81.49749823599996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.588957421875, {'test_accuracy': 0.0974}, 158.9490027919992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.6761181640625, {'test_accuracy': 0.1135}, 237.47107807499924)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 2.32427890625, {'test_accuracy': 0.0892}, 317.2076230389994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.6055080078125, {'test_accuracy': 0.1135}, 394.9630807939993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.3883890625, {'test_accuracy': 0.0983}, 472.81769499999973)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.9457388671875, {'test_accuracy': 0.1135}, 551.3559615699996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.517490625, {'test_accuracy': 0.0975}, 629.5985030739994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 2.6161373046875, {'test_accuracy': 0.1135}, 707.7754782789998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.740278125, {'test_accuracy': 0.0891}, 786.4106176619989)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 788.22s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 3.269107811923342
# INFO :      		round 2: 2.577815114537265
# INFO :      		round 3: 2.6703993257798695
# INFO :      		round 4: 2.323363259285589
# INFO :      		round 5: 2.6005949439646168
# INFO :      		round 6: 2.389354555665691
# INFO :      		round 7: 2.931102494067395
# INFO :      		round 8: 2.5131086336126955
# INFO :      		round 9: 2.612504794965035
# INFO :      		round 10: 2.730463607538693
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3040326171875
# INFO :      		round 1: 3.283187890625
# INFO :      		round 2: 2.588957421875
# INFO :      		round 3: 2.6761181640625
# INFO :      		round 4: 2.32427890625
# INFO :      		round 5: 2.6055080078125
# INFO :      		round 6: 2.3883890625
# INFO :      		round 7: 2.9457388671875
# INFO :      		round 8: 2.517490625
# INFO :      		round 9: 2.6161373046875
# INFO :      		round 10: 2.740278125
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0974),
# INFO :      	                   (1, 0.1135),
# INFO :      	                   (2, 0.0974),
# INFO :      	                   (3, 0.1135),
# INFO :      	                   (4, 0.0892),
# INFO :      	                   (5, 0.1135),
# INFO :      	                   (6, 0.0983),
# INFO :      	                   (7, 0.1135),
# INFO :      	                   (8, 0.0975),
# INFO :      	                   (9, 0.1135),
# INFO :      	                   (10, 0.0891)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">B</span>
#         <span>FedProx</span>
#     </h3>
# </div>

# %%
PROXIMAL_MU = 0.1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_prox_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_prox_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_prox_strategy = FedProx(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_prox_evaluate_fn,
        proximal_mu = PROXIMAL_MU
    )
fed_prox_server = Server(strategy=fed_prox_strategy, client_manager=SimpleClientManager())

# %%
fedprox_history = fl.simulation.start_simulation(
        server=fed_prox_server,
        client_fn=fed_prox_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_prox_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 16:58:57,011	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'memory': 18558728603.0, 'object_store_memory': 9279364300.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=6240) 2025-03-21 16:59:00.681957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=6240) 2025-03-21 16:59:00.726419: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=6240) 2025-03-21 16:59:00.740052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.30473125, {'test_accuracy': 0.0982}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.7620353515625, {'test_accuracy': 0.0904}, 82.41610484099874)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.4446984375, {'test_accuracy': 0.1135}, 159.7777876709988)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.3576146484375, {'test_accuracy': 0.1014}, 237.96983084199928)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 2.404976171875, {'test_accuracy': 0.1135}, 316.158805346)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.431973046875, {'test_accuracy': 0.1019}, 394.25953769899934)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.4759072265625, {'test_accuracy': 0.1135}, 471.40353560199947)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.565792578125, {'test_accuracy': 0.1009}, 549.3920946139988)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.732055859375, {'test_accuracy': 0.1135}, 627.4397692019993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 2.6013443359375, {'test_accuracy': 0.0995}, 705.778449726)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.8716123046875, {'test_accuracy': 0.101}, 783.500681554)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 785.31s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.757749711298163
# INFO :      		round 2: 2.4484649817891087
# INFO :      		round 3: 2.3582225338946667
# INFO :      		round 4: 2.4059703701571515
# INFO :      		round 5: 2.4307735966713606
# INFO :      		round 6: 2.4715590725110483
# INFO :      		round 7: 2.5683828364061148
# INFO :      		round 8: 2.7141302533750933
# INFO :      		round 9: 2.603273522782278
# INFO :      		round 10: 2.8507441103339115
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.30473125
# INFO :      		round 1: 2.7620353515625
# INFO :      		round 2: 2.4446984375
# INFO :      		round 3: 2.3576146484375
# INFO :      		round 4: 2.404976171875
# INFO :      		round 5: 2.431973046875
# INFO :      		round 6: 2.4759072265625
# INFO :      		round 7: 2.565792578125
# INFO :      		round 8: 2.732055859375
# INFO :      		round 9: 2.6013443359375
# INFO :      		round 10: 2.8716123046875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0982),
# INFO :      	                   (1, 0.0904),
# INFO :      	                   (2, 0.1135),
# INFO :      	                   (3, 0.1014),
# INFO :      	                   (4, 0.1135),
# INFO :      	                   (5, 0.1019),
# INFO :      	                   (6, 0.1135),
# INFO :      	                   (7, 0.1009),
# INFO :      	                   (8, 0.1135),
# INFO :      	                   (9, 0.0995),
# INFO :      	                   (10, 0.101)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>FedAdam</span>
#     </h3>
# </div>

# %%
BETA_1=0.9 
BETA_2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adam_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adam_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adam_strategy = FedAdam(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adam_evaluate_fn,
        initial_parameters = initial_parameters,
        beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_adam_server = Server(strategy=fed_adam_strategy, client_manager=SimpleClientManager())

# %%
fedadam_history = fl.simulation.start_simulation(
        server=fed_adam_server,
        client_fn=fed_adam_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adam_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 17:12:21,250	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18558256743.0, 'node:__internal_head__': 1.0, 'CPU': 4.0, 'object_store_memory': 9279128371.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3045787109375, {'test_accuracy': 0.1031}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (pid=6885) 2025-03-21 17:12:26.905900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=6885) 2025-03-21 17:12:27.040629: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=6883) 2025-03-21 17:12:27.037514: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1140.3722, {'test_accuracy': 0.1028}, 87.71342711000034)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 3658.6608, {'test_accuracy': 0.0958}, 184.15683816400087)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2432.7402, {'test_accuracy': 0.098}, 262.814404656001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 766.56, {'test_accuracy': 0.1135}, 340.2384246010006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 68.03843125, {'test_accuracy': 0.1032}, 419.0280578820002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.38921484375, {'test_accuracy': 0.1032}, 496.78926836900064)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.54005625, {'test_accuracy': 0.1028}, 573.9068936840013)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 3.77409453125, {'test_accuracy': 0.1028}, 649.9548065039999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 11.1394140625, {'test_accuracy': 0.1028}, 726.6723175960014)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 24.986890625, {'test_accuracy': 0.1028}, 804.377981302001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 806.10s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1127.5021319958748
# INFO :      		round 2: 3611.5623358280523
# INFO :      		round 3: 2414.290349816544
# INFO :      		round 4: 763.6997682699925
# INFO :      		round 5: 67.76800426154871
# INFO :      		round 6: 2.3916248871216066
# INFO :      		round 7: 2.5430942701450423
# INFO :      		round 8: 3.7765798498742815
# INFO :      		round 9: 11.202952221403764
# INFO :      		round 10: 25.196639688353763
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3045787109375
# INFO :      		round 1: 1140.3722
# INFO :      		round 2: 3658.6608
# INFO :      		round 3: 2432.7402
# INFO :      		round 4: 766.56
# INFO :      		round 5: 68.03843125
# INFO :      		round 6: 2.38921484375
# INFO :      		round 7: 2.54005625
# INFO :      		round 8: 3.77409453125
# INFO :      		round 9: 11.1394140625
# INFO :      		round 10: 24.986890625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1031),
# INFO :      	                   (1, 0.1028),
# INFO :      	                   (2, 0.0958),
# INFO :      	                   (3, 0.098),
# INFO :      	                   (4, 0.1135),
# INFO :      	                   (5, 0.1032),
# INFO :      	                   (6, 0.1032),
# INFO :      	                   (7, 0.1028),
# INFO :      	                   (8, 0.1028),
# INFO :      	                   (9, 0.1028),
# INFO :      	                   (10, 0.1028)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">D</span>
#         <span>FedAdagrad</span>
#     </h3>
# </div>

# %%
#work good Beta1=beta2=0
TAU  = 0.2
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adagrad_strategy = FedAdagrad(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
    tau=TAU
    )
fed_adagrad_server = Server(strategy=fed_adagrad_strategy, client_manager=SimpleClientManager())

# %%
fedadagrad_history = fl.simulation.start_simulation(
        server=fed_adagrad_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adagrad_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 17:25:57,643	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9278727782.0, 'memory': 18557455566.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=7531) 2025-03-21 17:26:02.396846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=7531) 2025-03-21 17:26:02.441155: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=7531) 2025-03-21 17:26:02.453743: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.306425390625, {'test_accuracy': 0.0982}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.3133591796875, {'test_accuracy': 0.0974}, 87.54222309400029)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.3492431640625, {'test_accuracy': 0.0974}, 166.48955783199926)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.3429142578125, {'test_accuracy': 0.0974}, 245.13778362300036)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 2.3250560546875, {'test_accuracy': 0.11}, 323.0176960509998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.32144921875, {'test_accuracy': 0.0984}, 403.02016428299976)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.3216912109375, {'test_accuracy': 0.1091}, 481.3593342189997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.321183984375, {'test_accuracy': 0.1204}, 561.0003096870005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.3199830078125, {'test_accuracy': 0.1607}, 639.7914661390005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 2.3130224609375, {'test_accuracy': 0.1873}, 720.5024685459994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.31035, {'test_accuracy': 0.1934}, 798.963450796)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 800.73s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.3130847744499548
# INFO :      		round 2: 2.3483928280563813
# INFO :      		round 3: 2.3421103668022027
# INFO :      		round 4: 2.324538969850445
# INFO :      		round 5: 2.321354959550263
# INFO :      		round 6: 2.321689286973176
# INFO :      		round 7: 2.3216312521692113
# INFO :      		round 8: 2.320868244482884
# INFO :      		round 9: 2.3139431463868876
# INFO :      		round 10: 2.3109537312951067
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.306425390625
# INFO :      		round 1: 2.3133591796875
# INFO :      		round 2: 2.3492431640625
# INFO :      		round 3: 2.3429142578125
# INFO :      		round 4: 2.3250560546875
# INFO :      		round 5: 2.32144921875
# INFO :      		round 6: 2.3216912109375
# INFO :      		round 7: 2.321183984375
# INFO :      		round 8: 2.3199830078125
# INFO :      		round 9: 2.3130224609375
# INFO :      		round 10: 2.31035
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0982),
# INFO :      	                   (1, 0.0974),
# INFO :      	                   (2, 0.0974),
# INFO :      	                   (3, 0.0974),
# INFO :      	                   (4, 0.11),
# INFO :      	                   (5, 0.0984),
# INFO :      	                   (6, 0.1091),
# INFO :      	                   (7, 0.1204),
# INFO :      	                   (8, 0.1607),
# INFO :      	                   (9, 0.1873),
# INFO :      	                   (10, 0.1934)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">E</span>
#         <span>FedYogi</span>
#     </h3>
# </div>

# %%
BETA1= 0.9
BETA2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_yogi_strategy = FedYogi(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
     beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_yogi_server = Server(strategy=fed_yogi_strategy, client_manager=SimpleClientManager())

# %%
fedyogi_history = fl.simulation.start_simulation(
        server=fed_yogi_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_yogi_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 17:39:30,067	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9277721395.0, 'memory': 18555442791.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=8184) 2025-03-21 17:39:36.323160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=8183) 2025-03-21 17:39:36.363362: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=8183) 2025-03-21 17:39:36.379480: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.30457734375, {'test_accuracy': 0.1135}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.313784375, {'test_accuracy': 0.1135}, 100.43139369500022)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.7735728515625, {'test_accuracy': 0.1135}, 183.9989477479994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 6.24678828125, {'test_accuracy': 0.1135}, 267.8656985969992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 7.34533984375, {'test_accuracy': 0.1009}, 350.268712699999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 7.1505453125, {'test_accuracy': 0.098}, 433.9150762169993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 9.3694953125, {'test_accuracy': 0.0974}, 525.7124651649992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 11.55620234375, {'test_accuracy': 0.1009}, 649.7021816069991)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 12.14189453125, {'test_accuracy': 0.0982}, 792.825052623999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 16.1660828125, {'test_accuracy': 0.0982}, 912.2815257549992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 13.2209828125, {'test_accuracy': 0.101}, 1033.991896378)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 1035.97s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.3143274178100954
# INFO :      		round 2: 2.774394021979008
# INFO :      		round 3: 6.230883174454712
# INFO :      		round 4: 7.3260079059225465
# INFO :      		round 5: 7.122999053068206
# INFO :      		round 6: 9.29988777669292
# INFO :      		round 7: 11.460141591026911
# INFO :      		round 8: 12.080417180713452
# INFO :      		round 9: 16.080985438704907
# INFO :      		round 10: 13.150175628721406
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.30457734375
# INFO :      		round 1: 2.313784375
# INFO :      		round 2: 2.7735728515625
# INFO :      		round 3: 6.24678828125
# INFO :      		round 4: 7.34533984375
# INFO :      		round 5: 7.1505453125
# INFO :      		round 6: 9.3694953125
# INFO :      		round 7: 11.55620234375
# INFO :      		round 8: 12.14189453125
# INFO :      		round 9: 16.1660828125
# INFO :      		round 10: 13.2209828125
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1135),
# INFO :      	                   (1, 0.1135),
# INFO :      	                   (2, 0.1135),
# INFO :      	                   (3, 0.1135),
# INFO :      	                   (4, 0.1009),
# INFO :      	                   (5, 0.098),
# INFO :      	                   (6, 0.0974),
# INFO :      	                   (7, 0.1009),
# INFO :      	                   (8, 0.0982),
# INFO :      	                   (9, 0.0982),
# INFO :      	                   (10, 0.101)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">F</span>
#         <span>FedNova</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_nova_client_fn = nova_gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS, LEARNING_RATE)
fed_nova_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_nova_strategy =FedNovaStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_nova_evaluate_fn,
)

fed_nova_server = FedNovaServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_nova_strategy,
    )

# %%
fednova_history = fl.simulation.start_simulation(
        server=fed_nova_server,
        client_fn=fed_nova_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_nova_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 17:57:01,397	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18559613339.0, 'object_store_memory': 9279806668.0, 'CPU': 4.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=8852) 2025-03-21 17:57:05.835804: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=8855) 2025-03-21 17:57:05.941509: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=8855) 2025-03-21 17:57:05.965114: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3079021484375, {'test_accuracy': 0.099}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.7438119140625, {'test_accuracy': 0.0892}, 140.37770360499962)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 8.63758671875, {'test_accuracy': 0.098}, 238.91661703799946)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 2.4143076171875, {'test_accuracy': 0.1028}, 317.83711584999946)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 5.7777625, {'test_accuracy': 0.1135}, 449.5547829039988)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 2.6553927734375, {'test_accuracy': 0.0892}, 538.4530732229996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 3.005383203125, {'test_accuracy': 0.0974}, 623.1781652520003)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 4.459255078125, {'test_accuracy': 0.098}, 700.8300209119989)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 2.9359869140625, {'test_accuracy': 0.0958}, 781.6694505449996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 2.770016015625, {'test_accuracy': 0.0982}, 859.7154163649993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 2.768209765625, {'test_accuracy': 0.0958}, 937.9150578179997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 939.74s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.731037370517621
# INFO :      		round 2: 8.600233828210289
# INFO :      		round 3: 2.41654914056881
# INFO :      		round 4: 5.804894941977615
# INFO :      		round 5: 2.6463949374949003
# INFO :      		round 6: 2.9916831085568987
# INFO :      		round 7: 4.463067579619323
# INFO :      		round 8: 2.9391528492851844
# INFO :      		round 9: 2.773074668753219
# INFO :      		round 10: 2.768933692560584
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3079021484375
# INFO :      		round 1: 2.7438119140625
# INFO :      		round 2: 8.63758671875
# INFO :      		round 3: 2.4143076171875
# INFO :      		round 4: 5.7777625
# INFO :      		round 5: 2.6553927734375
# INFO :      		round 6: 3.005383203125
# INFO :      		round 7: 4.459255078125
# INFO :      		round 8: 2.9359869140625
# INFO :      		round 9: 2.770016015625
# INFO :      		round 10: 2.768209765625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.099),
# INFO :      	                   (1, 0.0892),
# INFO :      	                   (2, 0.098),
# INFO :      	                   (3, 0.1028),
# INFO :      	                   (4, 0.1135),
# INFO :      	                   (5, 0.0892),
# INFO :      	                   (6, 0.0974),
# INFO :      	                   (7, 0.098),
# INFO :      	                   (8, 0.0958),
# INFO :      	                   (9, 0.0982),
# INFO :      	                   (10, 0.0958)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">G</span>
#         <span>FedScaffold</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
client_cv_dir = os.path.join("/kaggle/working/", "client_cvs")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_scaffold_client_fn =scaffold_gen_client_fn( trainloaders, valloaders,client_cv_dir,NUM_EPOCHS, LEARNING_RATE, model_cfg,device)
fed_scaffold_evaluate_fn = gen_evaluate_fn(testloader, 
                              device,model_cfg)

# %%
fed_scaffold_strategy =ScaffoldStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_scaffold_evaluate_fn,
)

fed_scaffold_server = ScaffoldServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_scaffold_strategy,
    model_cfg=model_cfg,
    )

# %%
fedscaffold_history = fl.simulation.start_simulation(
        server=fed_scaffold_server,
        client_fn=fed_scaffold_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_scaffold_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 18:13:05,544	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'memory': 18558512334.0, 'object_store_memory': 9279256166.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=9515) 2025-03-21 18:13:09.649353: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=9515) 2025-03-21 18:13:09.692871: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=9515) 2025-03-21 18:13:09.708874: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3057625, {'test_accuracy': 0.0824}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.5469552734375, {'test_accuracy': 0.1028}, 84.41614458200092)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 2.31677265625, {'test_accuracy': 0.0892}, 164.92325066900048)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 2.4053865234375, {'test_accuracy': 0.1028}, 245.71226885400029)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 2.3173087890625, {'test_accuracy': 0.0446}, 326.1470511000007)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 2.4236544921875, {'test_accuracy': 0.1028}, 406.3968537010005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 2.3199384765625, {'test_accuracy': 0.1135}, 485.54892626000037)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 2.442799609375, {'test_accuracy': 0.1028}, 566.3719712860002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 2.3256802734375, {'test_accuracy': 0.1135}, 648.1780540790005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 2.468158203125, {'test_accuracy': 0.1028}, 731.5282045410004)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 2.3360005859375, {'test_accuracy': 0.1135}, 813.1893982010006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 815.27s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.5389526671294456
# INFO :      		round 2: 2.3170773389738666
# INFO :      		round 3: 2.402005225201302
# INFO :      		round 4: 2.318062523987549
# INFO :      		round 5: 2.419846574173839
# INFO :      		round 6: 2.3209248842439147
# INFO :      		round 7: 2.438798636575792
# INFO :      		round 8: 2.326851282380596
# INFO :      		round 9: 2.463675157955442
# INFO :      		round 10: 2.3371846384808093
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3057625
# INFO :      		round 1: 2.5469552734375
# INFO :      		round 2: 2.31677265625
# INFO :      		round 3: 2.4053865234375
# INFO :      		round 4: 2.3173087890625
# INFO :      		round 5: 2.4236544921875
# INFO :      		round 6: 2.3199384765625
# INFO :      		round 7: 2.442799609375
# INFO :      		round 8: 2.3256802734375
# INFO :      		round 9: 2.468158203125
# INFO :      		round 10: 2.3360005859375
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0824),
# INFO :      	                   (1, 0.1028),
# INFO :      	                   (2, 0.0892),
# INFO :      	                   (3, 0.1028),
# INFO :      	                   (4, 0.0446),
# INFO :      	                   (5, 0.1028),
# INFO :      	                   (6, 0.1135),
# INFO :      	                   (7, 0.1028),
# INFO :      	                   (8, 0.1135),
# INFO :      	                   (9, 0.1028),
# INFO :      	                   (10, 0.1135)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">H</span>
#         <span>FedMoon</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "output_dim": 256,
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
MU = 5
TEMPERATURE = 0.5
MODEL_DIR = os.path.join("/kaggle/working/", "models")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_moon_client_fn =moon_gen_client_fn( trainloaders, valloaders,device,model_cfg,NUM_EPOCHS,
                                       LEARNING_RATE, MU,TEMPERATURE,MODEL_DIR)
fed_moon_evaluate_fn = moon_gen_evaluate_fn(testloader, 
                             device,model_cfg)

# %%
fed_moon_strategy =fl.server.strategy.FedAvg(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_moon_evaluate_fn,
)

# %%
fedmoon_history = fl.simulation.start_simulation(
        client_fn=fed_moon_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_moon_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 18:27:01,322	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18585821184.0, 'node:172.19.2.2': 1.0, 'object_store_memory': 9292910592.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=10165) 2025-03-21 18:27:05.622225: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=10162) 2025-03-21 18:27:05.713909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=10162) 2025-03-21 18:27:05.726391: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.301915407180786, {'test_accuracy': 0.1028}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.3023529052734375, {'test_accuracy': 0.1028}, 151.21765019299892)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.344841241836548, {'test_accuracy': 0.202}, 300.10862031799843)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.7506518363952637, {'test_accuracy': 0.0958}, 450.4598897199994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 4.656311511993408, {'test_accuracy': 0.101}, 602.5844504899997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.4916348457336426, {'test_accuracy': 0.1028}, 751.1478996089991)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.4745521545410156, {'test_accuracy': 0.0958}, 898.5953604549995)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 3.8154757022857666, {'test_accuracy': 0.101}, 1044.9097621389992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 3.431797742843628, {'test_accuracy': 0.0974}, 1192.4912830759986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 2.8213274478912354, {'test_accuracy': 0.1009}, 1343.0562576479988)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.7329845428466797, {'test_accuracy': 0.0982}, 1491.1150251309991)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 1492.66s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.301915407180786
# INFO :      		round 1: 2.3023529052734375
# INFO :      		round 2: 2.344841241836548
# INFO :      		round 3: 2.7506518363952637
# INFO :      		round 4: 4.656311511993408
# INFO :      		round 5: 2.4916348457336426
# INFO :      		round 6: 2.4745521545410156
# INFO :      		round 7: 3.8154757022857666
# INFO :      		round 8: 3.431797742843628
# INFO :      		round 9: 2.8213274478912354
# INFO :      		round 10: 2.7329845428466797
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1028),
# INFO :      	                   (1, 0.1028),
# INFO :      	                   (2, 0.202),
# INFO :      	                   (3, 0.0958),
# INFO :      	                   (4, 0.101),
# INFO :      	                   (5, 0.1028),
# INFO :      	                   (6, 0.0958),
# INFO :      	                   (7, 0.101),
# INFO :      	                   (8, 0.0974),
# INFO :      	                   (9, 0.1009),
# INFO :      	                   (10, 0.0982)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">L</span>
#         <span>Learning Curve: Test Accuracy vs. Communication Rounds</span>
#     </h3>
# </div>

# %%
plot_federated_learning_curves(
    fedavg_history,
    fedprox_history,
    fedadam_history,
    fedadagrad_history,
    fedyogi_history,
    fednova_history,
    fedscaffold_history,
    fedmoon_history,
    save_plot=True,
    filename='label Skew C_1.png'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# <a id='43'></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">3</span>
#         <span>Quantity-based label imbalance: Partitioning  with log-normal probability distribution and $C=2$</span>
#     </h2>
# </div>

# %%
C = 2
data_config = DictConfig({"name": "mnist", "partitioning": "label_quantity", "labels_per_client": C, "batch_size": BATCH_SIZE})

# %%
federated_dataset = FederatedDataset(data_config, num_clients=NUM_CLIENTS)
trainloaders, valloaders, testloader = federated_dataset.get_dataloaders()
dataset_stats = DatasetStatistics(federated_dataset)
# Display statistics
dataset_stats.plot_statistics()

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">A</span>
#         <span>FedAvg</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_avg_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_avg_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_avg_strategy = FedAvg(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_avg_evaluate_fn,
    )
fed_avg_server = Server(strategy=fed_avg_strategy, client_manager=SimpleClientManager())

# %%
fedavg_history = fl.simulation.start_simulation(
        server=fed_avg_server,
        client_fn=fed_avg_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_avg_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 18:52:28,038	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'node:172.19.2.2': 1.0, 'memory': 18554572800.0, 'object_store_memory': 9277286400.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=10884) 2025-03-21 18:52:32.815304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=10884) 2025-03-21 18:52:32.857938: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=10884) 2025-03-21 18:52:32.870635: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3079732421875, {'test_accuracy': 0.1108}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.1690236328125, {'test_accuracy': 0.1218}, 86.86304415800078)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 1.713951953125, {'test_accuracy': 0.4506}, 165.89281153000047)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.4856453125, {'test_accuracy': 0.5163}, 248.49441115900117)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.3311892578125, {'test_accuracy': 0.5711}, 329.6995421880001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.1935228515625, {'test_accuracy': 0.6196}, 411.4738993330011)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 1.11872041015625, {'test_accuracy': 0.6252}, 492.3657349620007)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 1.0372640625, {'test_accuracy': 0.6551}, 572.9882252030002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 1.05918330078125, {'test_accuracy': 0.6548}, 653.0886802719997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.92383310546875, {'test_accuracy': 0.6886}, 738.7402326620013)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.89550625, {'test_accuracy': 0.7059}, 823.6398401469996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 825.50s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.170178391915545
# INFO :      		round 2: 1.7206142832777518
# INFO :      		round 3: 1.4897209768796384
# INFO :      		round 4: 1.330214918405439
# INFO :      		round 5: 1.1829719032020347
# INFO :      		round 6: 1.102277361223159
# INFO :      		round 7: 1.0248339080333313
# INFO :      		round 8: 1.0444779408783391
# INFO :      		round 9: 0.916154364489634
# INFO :      		round 10: 0.8887236883483199
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3079732421875
# INFO :      		round 1: 2.1690236328125
# INFO :      		round 2: 1.713951953125
# INFO :      		round 3: 1.4856453125
# INFO :      		round 4: 1.3311892578125
# INFO :      		round 5: 1.1935228515625
# INFO :      		round 6: 1.11872041015625
# INFO :      		round 7: 1.0372640625
# INFO :      		round 8: 1.05918330078125
# INFO :      		round 9: 0.92383310546875
# INFO :      		round 10: 0.89550625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1108),
# INFO :      	                   (1, 0.1218),
# INFO :      	                   (2, 0.4506),
# INFO :      	                   (3, 0.5163),
# INFO :      	                   (4, 0.5711),
# INFO :      	                   (5, 0.6196),
# INFO :      	                   (6, 0.6252),
# INFO :      	                   (7, 0.6551),
# INFO :      	                   (8, 0.6548),
# INFO :      	                   (9, 0.6886),
# INFO :      	                   (10, 0.7059)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">B</span>
#         <span>FedProx</span>
#     </h3>
# </div>

# %%
PROXIMAL_MU = 0.1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_prox_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_prox_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_prox_strategy = FedProx(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_prox_evaluate_fn,
        proximal_mu = PROXIMAL_MU
    )
fed_prox_server = Server(strategy=fed_prox_strategy, client_manager=SimpleClientManager())

# %%
fedprox_history = fl.simulation.start_simulation(
        server=fed_prox_server,
        client_fn=fed_prox_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_prox_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 19:06:35,047	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'object_store_memory': 9273816268.0, 'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18547632539.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=11535) 2025-03-21 19:06:39.795773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=11535) 2025-03-21 19:06:39.836554: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=11535) 2025-03-21 19:06:39.849022: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3046576171875, {'test_accuracy': 0.0958}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.236752734375, {'test_accuracy': 0.1161}, 84.93573225100045)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 1.79638359375, {'test_accuracy': 0.3641}, 165.1511298810001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.5583119140625, {'test_accuracy': 0.4581}, 247.54092131300058)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.42494697265625, {'test_accuracy': 0.5289}, 333.5861084140015)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.3890884765625, {'test_accuracy': 0.5668}, 418.132654852001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 1.258728515625, {'test_accuracy': 0.6069}, 498.413135286999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 1.18225634765625, {'test_accuracy': 0.6319}, 581.7440114970013)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 1.13439931640625, {'test_accuracy': 0.6495}, 660.1956198920016)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 1.0872416015625, {'test_accuracy': 0.6316}, 743.5342489110008)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 1.05539375, {'test_accuracy': 0.6369}, 825.5303243790004)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 827.33s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.227722427902667
# INFO :      		round 2: 1.792177713503929
# INFO :      		round 3: 1.5443007240899909
# INFO :      		round 4: 1.4064385599449736
# INFO :      		round 5: 1.3655288781395944
# INFO :      		round 6: 1.2433426837109844
# INFO :      		round 7: 1.170519566973415
# INFO :      		round 8: 1.1214729823501435
# INFO :      		round 9: 1.0848892815616153
# INFO :      		round 10: 1.054129625878004
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3046576171875
# INFO :      		round 1: 2.236752734375
# INFO :      		round 2: 1.79638359375
# INFO :      		round 3: 1.5583119140625
# INFO :      		round 4: 1.42494697265625
# INFO :      		round 5: 1.3890884765625
# INFO :      		round 6: 1.258728515625
# INFO :      		round 7: 1.18225634765625
# INFO :      		round 8: 1.13439931640625
# INFO :      		round 9: 1.0872416015625
# INFO :      		round 10: 1.05539375
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0958),
# INFO :      	                   (1, 0.1161),
# INFO :      	                   (2, 0.3641),
# INFO :      	                   (3, 0.4581),
# INFO :      	                   (4, 0.5289),
# INFO :      	                   (5, 0.5668),
# INFO :      	                   (6, 0.6069),
# INFO :      	                   (7, 0.6319),
# INFO :      	                   (8, 0.6495),
# INFO :      	                   (9, 0.6316),
# INFO :      	                   (10, 0.6369)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>FedAdam</span>
#     </h3>
# </div>

# %%
BETA_1=0.9 
BETA_2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adam_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adam_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adam_strategy = FedAdam(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adam_evaluate_fn,
        initial_parameters = initial_parameters,
        beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_adam_server = Server(strategy=fed_adam_strategy, client_manager=SimpleClientManager())

# %%
fedadam_history = fl.simulation.start_simulation(
        server=fed_adam_server,
        client_fn=fed_adam_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adam_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 19:20:43,703	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18545978574.0, 'object_store_memory': 9272989286.0, 'CPU': 4.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=12187) 2025-03-21 19:20:48.502673: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=12187) 2025-03-21 19:20:48.546383: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=12187) 2025-03-21 19:20:48.559566: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.301587890625, {'test_accuracy': 0.1264}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 52.83006875, {'test_accuracy': 0.1944}, 93.06083262999891)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 38.227709375, {'test_accuracy': 0.1739}, 180.12146555000072)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 3.38274921875, {'test_accuracy': 0.294}, 263.7926927619992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 4.691994140625, {'test_accuracy': 0.2991}, 345.11881584799994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 4.8375046875, {'test_accuracy': 0.4659}, 425.07275761100027)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 5.89348203125, {'test_accuracy': 0.5695}, 505.68013991299813)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 8.39294296875, {'test_accuracy': 0.5492}, 592.405012012001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 6.7306296875, {'test_accuracy': 0.5535}, 684.5316127410006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 5.73529140625, {'test_accuracy': 0.6099}, 775.2400746269996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 7.18780546875, {'test_accuracy': 0.5471}, 869.714444063)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 871.64s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 51.46853098610821
# INFO :      		round 2: 38.32755531393756
# INFO :      		round 3: 3.383108852345114
# INFO :      		round 4: 4.587741529195879
# INFO :      		round 5: 4.689787638952973
# INFO :      		round 6: 5.820679282346698
# INFO :      		round 7: 8.355665049998336
# INFO :      		round 8: 6.704388408883598
# INFO :      		round 9: 5.926387748845524
# INFO :      		round 10: 7.30579438833916
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.301587890625
# INFO :      		round 1: 52.83006875
# INFO :      		round 2: 38.227709375
# INFO :      		round 3: 3.38274921875
# INFO :      		round 4: 4.691994140625
# INFO :      		round 5: 4.8375046875
# INFO :      		round 6: 5.89348203125
# INFO :      		round 7: 8.39294296875
# INFO :      		round 8: 6.7306296875
# INFO :      		round 9: 5.73529140625
# INFO :      		round 10: 7.18780546875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1264),
# INFO :      	                   (1, 0.1944),
# INFO :      	                   (2, 0.1739),
# INFO :      	                   (3, 0.294),
# INFO :      	                   (4, 0.2991),
# INFO :      	                   (5, 0.4659),
# INFO :      	                   (6, 0.5695),
# INFO :      	                   (7, 0.5492),
# INFO :      	                   (8, 0.5535),
# INFO :      	                   (9, 0.6099),
# INFO :      	                   (10, 0.5471)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">D</span>
#         <span>FedAdagrad</span>
#     </h3>
# </div>

# %%
#work good Beta1=beta2=0
TAU  = 0.2
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adagrad_strategy = FedAdagrad(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
    tau=TAU
    )
fed_adagrad_server = Server(strategy=fed_adagrad_strategy, client_manager=SimpleClientManager())

# %%
fedadagrad_history = fl.simulation.start_simulation(
        server=fed_adagrad_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adagrad_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 19:35:26,676	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'CPU': 4.0, 'object_store_memory': 9272690688.0, 'memory': 18545381376.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=12844) 2025-03-21 19:35:31.245738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=12844) 2025-03-21 19:35:31.361947: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=12844) 2025-03-21 19:35:31.390222: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.3059828125, {'test_accuracy': 0.1032}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.276659765625, {'test_accuracy': 0.1032}, 92.38551089799876)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.18671796875, {'test_accuracy': 0.2641}, 175.37717838299795)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.021821484375, {'test_accuracy': 0.3094}, 255.39428447599857)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.8103484375, {'test_accuracy': 0.4025}, 335.13590576099887)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.61832646484375, {'test_accuracy': 0.4526}, 421.9311889569981)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 1.45536962890625, {'test_accuracy': 0.4888}, 502.24549021599887)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 1.3474798828125, {'test_accuracy': 0.5268}, 580.4388275969977)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 1.2633302734375, {'test_accuracy': 0.5638}, 662.8396038749997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 1.22388837890625, {'test_accuracy': 0.5953}, 742.972763957001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 1.1731681640625, {'test_accuracy': 0.6087}, 823.4257427240009)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 825.27s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.2774307072808884
# INFO :      		round 2: 2.1868829372428276
# INFO :      		round 3: 2.023178329658667
# INFO :      		round 4: 1.813160481266025
# INFO :      		round 5: 1.6212119088956374
# INFO :      		round 6: 1.4568505251377797
# INFO :      		round 7: 1.3457925287458279
# INFO :      		round 8: 1.260157472834774
# INFO :      		round 9: 1.2166598460791607
# INFO :      		round 10: 1.166959540022722
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3059828125
# INFO :      		round 1: 2.276659765625
# INFO :      		round 2: 2.18671796875
# INFO :      		round 3: 2.021821484375
# INFO :      		round 4: 1.8103484375
# INFO :      		round 5: 1.61832646484375
# INFO :      		round 6: 1.45536962890625
# INFO :      		round 7: 1.3474798828125
# INFO :      		round 8: 1.2633302734375
# INFO :      		round 9: 1.22388837890625
# INFO :      		round 10: 1.1731681640625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1032),
# INFO :      	                   (1, 0.1032),
# INFO :      	                   (2, 0.2641),
# INFO :      	                   (3, 0.3094),
# INFO :      	                   (4, 0.4025),
# INFO :      	                   (5, 0.4526),
# INFO :      	                   (6, 0.4888),
# INFO :      	                   (7, 0.5268),
# INFO :      	                   (8, 0.5638),
# INFO :      	                   (9, 0.5953),
# INFO :      	                   (10, 0.6087)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">E</span>
#         <span>FedYogi</span>
#     </h3>
# </div>

# %%
BETA1= 0.9
BETA2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_yogi_strategy = FedYogi(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
     beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_yogi_server = Server(strategy=fed_yogi_strategy, client_manager=SimpleClientManager())

# %%
fedyogi_history = fl.simulation.start_simulation(
        server=fed_yogi_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_yogi_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 19:49:23,356	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18544287744.0, 'object_store_memory': 9272143872.0, 'CPU': 4.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=13493) 2025-03-21 19:49:28.464704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=13493) 2025-03-21 19:49:28.507193: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=13493) 2025-03-21 19:49:28.519862: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.303030078125, {'test_accuracy': 0.1103}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.284391015625, {'test_accuracy': 0.219}, 87.12332142200103)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.222176953125, {'test_accuracy': 0.1797}, 172.17696484100088)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.2792103515625, {'test_accuracy': 0.201}, 259.722565414002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 2.49543359375, {'test_accuracy': 0.3372}, 341.6159286059992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.35834296875, {'test_accuracy': 0.3935}, 423.9237685480002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.131659375, {'test_accuracy': 0.5439}, 501.2387535650014)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.1943025390625, {'test_accuracy': 0.5796}, 584.5546530510001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.354015234375, {'test_accuracy': 0.5758}, 663.9525592919999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 2.411640234375, {'test_accuracy': 0.5837}, 746.4279492810019)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.269731640625, {'test_accuracy': 0.6097}, 826.0763635889998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 827.89s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.285153217013425
# INFO :      		round 2: 2.221817119047978
# INFO :      		round 3: 2.2714454475892794
# INFO :      		round 4: 2.4752049561437715
# INFO :      		round 5: 2.3044123635876668
# INFO :      		round 6: 2.0488566800044716
# INFO :      		round 7: 2.0727228724926685
# INFO :      		round 8: 2.2146528692022773
# INFO :      		round 9: 2.2754057957988865
# INFO :      		round 10: 2.1670084253164803
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.303030078125
# INFO :      		round 1: 2.284391015625
# INFO :      		round 2: 2.222176953125
# INFO :      		round 3: 2.2792103515625
# INFO :      		round 4: 2.49543359375
# INFO :      		round 5: 2.35834296875
# INFO :      		round 6: 2.131659375
# INFO :      		round 7: 2.1943025390625
# INFO :      		round 8: 2.354015234375
# INFO :      		round 9: 2.411640234375
# INFO :      		round 10: 2.269731640625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1103),
# INFO :      	                   (1, 0.219),
# INFO :      	                   (2, 0.1797),
# INFO :      	                   (3, 0.201),
# INFO :      	                   (4, 0.3372),
# INFO :      	                   (5, 0.3935),
# INFO :      	                   (6, 0.5439),
# INFO :      	                   (7, 0.5796),
# INFO :      	                   (8, 0.5758),
# INFO :      	                   (9, 0.5837),
# INFO :      	                   (10, 0.6097)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">F</span>
#         <span>FedNova</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_nova_client_fn = nova_gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS, LEARNING_RATE)
fed_nova_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_nova_strategy =FedNovaStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_nova_evaluate_fn,
)

fed_nova_server = FedNovaServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_nova_strategy,
    )

# %%
fednova_history = fl.simulation.start_simulation(
        server=fed_nova_server,
        client_fn=fed_nova_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_nova_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 20:03:23,831	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9272104550.0, 'memory': 18544209102.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=14143) 2025-03-21 20:03:28.035948: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=14143) 2025-03-21 20:03:28.077222: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=14143) 2025-03-21 20:03:28.089803: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.305503125, {'test_accuracy': 0.0776}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2322380859375, {'test_accuracy': 0.3942}, 77.20470056699924)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 1.7201109375, {'test_accuracy': 0.4559}, 158.09438433799733)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 1.399139453125, {'test_accuracy': 0.5207}, 236.79809023099733)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 0.788478662109375, {'test_accuracy': 0.7702}, 314.06683854199946)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 1.07358779296875, {'test_accuracy': 0.6167}, 392.3273767849969)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 0.649557080078125, {'test_accuracy': 0.7591}, 471.81863953399807)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 1.11444580078125, {'test_accuracy': 0.6098}, 548.2691594619973)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 0.525011328125, {'test_accuracy': 0.8113}, 628.5143426429968)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 0.71045009765625, {'test_accuracy': 0.7483}, 710.9230706849994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 0.3493888671875, {'test_accuracy': 0.8871}, 794.7157616329969)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 796.60s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.2309066826547554
# INFO :      		round 2: 1.7191542106036646
# INFO :      		round 3: 1.3932207516772832
# INFO :      		round 4: 0.8019038548759861
# INFO :      		round 5: 1.0597902730765991
# INFO :      		round 6: 0.6611164190055332
# INFO :      		round 7: 1.1013452646904334
# INFO :      		round 8: 0.5303810189623351
# INFO :      		round 9: 0.7075442209404841
# INFO :      		round 10: 0.3533909707789226
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.305503125
# INFO :      		round 1: 2.2322380859375
# INFO :      		round 2: 1.7201109375
# INFO :      		round 3: 1.399139453125
# INFO :      		round 4: 0.788478662109375
# INFO :      		round 5: 1.07358779296875
# INFO :      		round 6: 0.649557080078125
# INFO :      		round 7: 1.11444580078125
# INFO :      		round 8: 0.525011328125
# INFO :      		round 9: 0.71045009765625
# INFO :      		round 10: 0.3493888671875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0776),
# INFO :      	                   (1, 0.3942),
# INFO :      	                   (2, 0.4559),
# INFO :      	                   (3, 0.5207),
# INFO :      	                   (4, 0.7702),
# INFO :      	                   (5, 0.6167),
# INFO :      	                   (6, 0.7591),
# INFO :      	                   (7, 0.6098),
# INFO :      	                   (8, 0.8113),
# INFO :      	                   (9, 0.7483),
# INFO :      	                   (10, 0.8871)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">G</span>
#         <span>FedScaffold</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
client_cv_dir = os.path.join("/kaggle/working/", "client_cvs")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_scaffold_client_fn =scaffold_gen_client_fn( trainloaders, valloaders,client_cv_dir,NUM_EPOCHS, LEARNING_RATE, model_cfg,device)
fed_scaffold_evaluate_fn = gen_evaluate_fn(testloader, 
                              device,model_cfg)

# %%
fed_scaffold_strategy =ScaffoldStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_scaffold_evaluate_fn,
)

fed_scaffold_server = ScaffoldServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_scaffold_strategy,
    model_cfg=model_cfg,
    )

# %%
fedscaffold_history = fl.simulation.start_simulation(
        server=fed_scaffold_server,
        client_fn=fed_scaffold_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_scaffold_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 20:17:02,216	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9271450828.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'memory': 18542901659.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=14788) 2025-03-21 20:17:07.136914: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=14788) 2025-03-21 20:17:07.180237: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=14788) 2025-03-21 20:17:07.193268: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.305249609375, {'test_accuracy': 0.1048}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2132228515625, {'test_accuracy': 0.2056}, 82.73728284800018)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 2.0922875, {'test_accuracy': 0.2775}, 166.6408443600012)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 2.0903380859375, {'test_accuracy': 0.2451}, 249.83588560600037)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 2.161130078125, {'test_accuracy': 0.2573}, 330.2273841480019)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 2.145545703125, {'test_accuracy': 0.2537}, 414.6417385200002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 2.2384451171875, {'test_accuracy': 0.2204}, 500.3797567619986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 2.2515642578125, {'test_accuracy': 0.2204}, 579.2002171230015)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 2.3978365234375, {'test_accuracy': 0.2128}, 660.1750304859997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 2.373943359375, {'test_accuracy': 0.2134}, 745.1507967180005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 2.5305287109375, {'test_accuracy': 0.2139}, 823.5622224409999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 825.49s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.205594784225197
# INFO :      		round 2: 2.093838560153684
# INFO :      		round 3: 2.0863170187904796
# INFO :      		round 4: 2.1567018951148764
# INFO :      		round 5: 2.1397648102646576
# INFO :      		round 6: 2.233480013480676
# INFO :      		round 7: 2.2453702686427532
# INFO :      		round 8: 2.3866161769583782
# INFO :      		round 9: 2.3613220668216863
# INFO :      		round 10: 2.5113017981006664
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.305249609375
# INFO :      		round 1: 2.2132228515625
# INFO :      		round 2: 2.0922875
# INFO :      		round 3: 2.0903380859375
# INFO :      		round 4: 2.161130078125
# INFO :      		round 5: 2.145545703125
# INFO :      		round 6: 2.2384451171875
# INFO :      		round 7: 2.2515642578125
# INFO :      		round 8: 2.3978365234375
# INFO :      		round 9: 2.373943359375
# INFO :      		round 10: 2.5305287109375
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1048),
# INFO :      	                   (1, 0.2056),
# INFO :      	                   (2, 0.2775),
# INFO :      	                   (3, 0.2451),
# INFO :      	                   (4, 0.2573),
# INFO :      	                   (5, 0.2537),
# INFO :      	                   (6, 0.2204),
# INFO :      	                   (7, 0.2204),
# INFO :      	                   (8, 0.2128),
# INFO :      	                   (9, 0.2134),
# INFO :      	                   (10, 0.2139)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">H</span>
#         <span>FedMoon</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "output_dim": 256,
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
MU = 5
TEMPERATURE = 0.5
MODEL_DIR = os.path.join("/kaggle/working/", "models")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_moon_client_fn =moon_gen_client_fn( trainloaders, valloaders,device,model_cfg,NUM_EPOCHS,
                                       LEARNING_RATE, MU,TEMPERATURE,MODEL_DIR)
fed_moon_evaluate_fn = moon_gen_evaluate_fn(testloader, 
                             device,model_cfg)

# %%
fed_moon_strategy =fl.server.strategy.FedAvg(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_moon_evaluate_fn,
)

# %%
fedmoon_history = fl.simulation.start_simulation(
        client_fn=fed_moon_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_moon_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 20:31:11,472	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18612026574.0, 'object_store_memory': 9306013286.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=15440) 2025-03-21 20:31:15.336463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=15440) 2025-03-21 20:31:15.376806: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=15440) 2025-03-21 20:31:15.389095: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3029887676239014, {'test_accuracy': 0.1032}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.6331372261047363, {'test_accuracy': 0.0982}, 149.90573797199977)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.1877522468566895, {'test_accuracy': 0.1826}, 296.6218742229976)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 2.644221782684326, {'test_accuracy': 0.1963}, 442.6787007919993)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 2.3700952529907227, {'test_accuracy': 0.2621}, 596.5510128679998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 2.187448263168335, {'test_accuracy': 0.279}, 749.5043099329996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 2.21513032913208, {'test_accuracy': 0.4426}, 895.7788952160008)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.214439630508423, {'test_accuracy': 0.4231}, 1048.4029108769973)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.6213114261627197, {'test_accuracy': 0.3955}, 1198.4015333520001)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 3.0811562538146973, {'test_accuracy': 0.3956}, 1348.6425709329997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.0149855613708496, {'test_accuracy': 0.3142}, 1502.1926855599995)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 1503.76s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3029887676239014
# INFO :      		round 1: 2.6331372261047363
# INFO :      		round 2: 2.1877522468566895
# INFO :      		round 3: 2.644221782684326
# INFO :      		round 4: 2.3700952529907227
# INFO :      		round 5: 2.187448263168335
# INFO :      		round 6: 2.21513032913208
# INFO :      		round 7: 2.214439630508423
# INFO :      		round 8: 2.6213114261627197
# INFO :      		round 9: 3.0811562538146973
# INFO :      		round 10: 2.0149855613708496
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1032),
# INFO :      	                   (1, 0.0982),
# INFO :      	                   (2, 0.1826),
# INFO :      	                   (3, 0.1963),
# INFO :      	                   (4, 0.2621),
# INFO :      	                   (5, 0.279),
# INFO :      	                   (6, 0.4426),
# INFO :      	                   (7, 0.4231),
# INFO :      	                   (8, 0.3955),
# INFO :      	                   (9, 0.3956),
# INFO :      	                   (10, 0.3142)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">L</span>
#         <span>Learning Curve: Test Accuracy vs. Communication Rounds</span>
#     </h3>
# </div>

# %%
plot_federated_learning_curves(
    fedavg_history,
    fedprox_history,
    fedadam_history,
    fedadagrad_history,
    fedyogi_history,
    fednova_history,
    fedscaffold_history,
    fedmoon_history,
    save_plot=True,
    filename='label Skew C_2.png'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# <a id='44'></a>
# <div style="border-left: 8px solid #3498db; border-radius: 0 20px 20px 0; padding: 20px; margin: 25px 0 25px 30px; box-shadow: 5px 5px 15px rgba(0,0,0,0.1); background: linear-gradient(to right, #EBF5FB, #D6EAF8);">
#     <h2 style="font-size: 28px; font-weight: bold; color: #2C3E50; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 3px 10px; border-radius: 10px; margin-right: 15px; font-size: 22px; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);">4</span>
#         <span>Quantity-based label imbalance: Partitioning  with log-normal probability distribution and $C=3$</span>
#     </h2>
# </div>

# %%
C = 3
data_config = DictConfig({"name": "mnist", "partitioning": "label_quantity", "labels_per_client": C, "batch_size": BATCH_SIZE})

# %%
federated_dataset = FederatedDataset(data_config, num_clients=NUM_CLIENTS)
trainloaders, valloaders, testloader = federated_dataset.get_dataloaders()
dataset_stats = DatasetStatistics(federated_dataset)
# Display statistics
dataset_stats.plot_statistics()

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">A</span>
#         <span>FedAvg</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_avg_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_avg_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_avg_strategy = FedAvg(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_avg_evaluate_fn,
    )
fed_avg_server = Server(strategy=fed_avg_strategy, client_manager=SimpleClientManager())

# %%
fedavg_history = fl.simulation.start_simulation(
        server=fed_avg_server,
        client_fn=fed_avg_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_avg_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 20:56:49,675	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'node:172.19.2.2': 1.0, 'object_store_memory': 9271727308.0, 'memory': 18543454619.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=16160) 2025-03-21 20:56:53.902952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=16160) 2025-03-21 20:56:53.957750: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=16160) 2025-03-21 20:56:53.971397: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.304765234375, {'test_accuracy': 0.1009}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.8048796875, {'test_accuracy': 0.438}, 85.55125173799752)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 0.93717158203125, {'test_accuracy': 0.7852}, 163.59658138899977)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.57243564453125, {'test_accuracy': 0.8313}, 244.46661401600068)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.429115625, {'test_accuracy': 0.8512}, 324.3580122249987)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.334862548828125, {'test_accuracy': 0.8811}, 403.29947334199824)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.3153542724609375, {'test_accuracy': 0.887}, 485.4941349569999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.258311083984375, {'test_accuracy': 0.9108}, 566.8772317869989)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.204239794921875, {'test_accuracy': 0.9289}, 647.6440879319998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.1895606689453125, {'test_accuracy': 0.9346}, 726.0643296550006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.18547838134765626, {'test_accuracy': 0.9383}, 806.6608309639996)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 808.44s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.8126935147563052
# INFO :      		round 2: 0.9442892943152396
# INFO :      		round 3: 0.5767362391183136
# INFO :      		round 4: 0.43275010468464675
# INFO :      		round 5: 0.3369880397882533
# INFO :      		round 6: 0.3159638844299953
# INFO :      		round 7: 0.25897849705738263
# INFO :      		round 8: 0.20378586308373522
# INFO :      		round 9: 0.18823723975472692
# INFO :      		round 10: 0.1838086962650178
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.304765234375
# INFO :      		round 1: 1.8048796875
# INFO :      		round 2: 0.93717158203125
# INFO :      		round 3: 0.57243564453125
# INFO :      		round 4: 0.429115625
# INFO :      		round 5: 0.334862548828125
# INFO :      		round 6: 0.3153542724609375
# INFO :      		round 7: 0.258311083984375
# INFO :      		round 8: 0.204239794921875
# INFO :      		round 9: 0.1895606689453125
# INFO :      		round 10: 0.18547838134765626
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1009),
# INFO :      	                   (1, 0.438),
# INFO :      	                   (2, 0.7852),
# INFO :      	                   (3, 0.8313),
# INFO :      	                   (4, 0.8512),
# INFO :      	                   (5, 0.8811),
# INFO :      	                   (6, 0.887),
# INFO :      	                   (7, 0.9108),
# INFO :      	                   (8, 0.9289),
# INFO :      	                   (9, 0.9346),
# INFO :      	                   (10, 0.9383)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">B</span>
#         <span>FedProx</span>
#     </h3>
# </div>

# %%
PROXIMAL_MU = 0.1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_prox_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_prox_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_prox_strategy = FedProx(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_prox_evaluate_fn,
        proximal_mu = PROXIMAL_MU
    )
fed_prox_server = Server(strategy=fed_prox_strategy, client_manager=SimpleClientManager())

# %%
fedprox_history = fl.simulation.start_simulation(
        server=fed_prox_server,
        client_fn=fed_prox_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_prox_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 21:10:40,916	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9268577894.0, 'memory': 18537155790.0, 'node:__internal_head__': 1.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=16809) 2025-03-21 21:10:44.994766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=16809) 2025-03-21 21:10:45.045663: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=16809) 2025-03-21 21:10:45.077281: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3044384765625, {'test_accuracy': 0.1198}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.968261328125, {'test_accuracy': 0.4128}, 83.8803104419967)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 1.04013349609375, {'test_accuracy': 0.7844}, 166.9271983409999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 0.589240283203125, {'test_accuracy': 0.8446}, 249.2605455749981)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 0.42856328125, {'test_accuracy': 0.8753}, 330.0071195379969)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 0.32642001953125, {'test_accuracy': 0.8903}, 408.7640281499989)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.2707304443359375, {'test_accuracy': 0.9086}, 488.2065558909999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.22518623046875, {'test_accuracy': 0.9212}, 567.3088749029994)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.2158321044921875, {'test_accuracy': 0.9262}, 645.9021802649986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.1960438720703125, {'test_accuracy': 0.9316}, 727.6651623389989)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.1940855712890625, {'test_accuracy': 0.9336}, 806.1088614289984)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 807.92s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.9594695302821676
# INFO :      		round 2: 1.0461592011296619
# INFO :      		round 3: 0.5941330710483452
# INFO :      		round 4: 0.4315383521788711
# INFO :      		round 5: 0.3322803722111954
# INFO :      		round 6: 0.2801146963221317
# INFO :      		round 7: 0.23517557001292855
# INFO :      		round 8: 0.22977868780381885
# INFO :      		round 9: 0.20892824940228086
# INFO :      		round 10: 0.20608715737600491
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3044384765625
# INFO :      		round 1: 1.968261328125
# INFO :      		round 2: 1.04013349609375
# INFO :      		round 3: 0.589240283203125
# INFO :      		round 4: 0.42856328125
# INFO :      		round 5: 0.32642001953125
# INFO :      		round 6: 0.2707304443359375
# INFO :      		round 7: 0.22518623046875
# INFO :      		round 8: 0.2158321044921875
# INFO :      		round 9: 0.1960438720703125
# INFO :      		round 10: 0.1940855712890625
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1198),
# INFO :      	                   (1, 0.4128),
# INFO :      	                   (2, 0.7844),
# INFO :      	                   (3, 0.8446),
# INFO :      	                   (4, 0.8753),
# INFO :      	                   (5, 0.8903),
# INFO :      	                   (6, 0.9086),
# INFO :      	                   (7, 0.9212),
# INFO :      	                   (8, 0.9262),
# INFO :      	                   (9, 0.9316),
# INFO :      	                   (10, 0.9336)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">C</span>
#         <span>FedAdam</span>
#     </h3>
# </div>

# %%
BETA_1=0.9 
BETA_2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adam_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adam_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adam_strategy = FedAdam(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adam_evaluate_fn,
        initial_parameters = initial_parameters,
        beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_adam_server = Server(strategy=fed_adam_strategy, client_manager=SimpleClientManager())

# %%
fedadam_history = fl.simulation.start_simulation(
        server=fed_adam_server,
        client_fn=fed_adam_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adam_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 21:24:31,300	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9267945062.0, 'memory': 18535890126.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=17456) 2025-03-21 21:24:35.824039: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=17453) 2025-03-21 21:24:35.790318: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=17453) 2025-03-21 21:24:35.802471: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.303888671875, {'test_accuracy': 0.0906}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 25.004925, {'test_accuracy': 0.1936}, 86.57451766899976)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 20.29345625, {'test_accuracy': 0.4555}, 165.05104614599986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 15.97156875, {'test_accuracy': 0.1599}, 249.2840176259997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 9.329390625, {'test_accuracy': 0.2458}, 331.8352827710005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 6.380702734375, {'test_accuracy': 0.4601}, 417.3809458959986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 3.4828828125, {'test_accuracy': 0.5737}, 498.70918945800076)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 2.5896802734375, {'test_accuracy': 0.6921}, 579.8585389779983)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 2.034230078125, {'test_accuracy': 0.8148}, 664.7993136660007)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 1.77751953125, {'test_accuracy': 0.8589}, 749.5419828140002)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 2.710341796875, {'test_accuracy': 0.8351}, 841.8091995529976)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 843.62s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 24.328017928860802
# INFO :      		round 2: 20.72541616470044
# INFO :      		round 3: 15.727841394597833
# INFO :      		round 4: 9.034659563689752
# INFO :      		round 5: 6.19687664232421
# INFO :      		round 6: 3.4295929712700883
# INFO :      		round 7: 2.4922827115349215
# INFO :      		round 8: 1.9568855209702758
# INFO :      		round 9: 1.679898311815429
# INFO :      		round 10: 2.5111062581982586
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.303888671875
# INFO :      		round 1: 25.004925
# INFO :      		round 2: 20.29345625
# INFO :      		round 3: 15.97156875
# INFO :      		round 4: 9.329390625
# INFO :      		round 5: 6.380702734375
# INFO :      		round 6: 3.4828828125
# INFO :      		round 7: 2.5896802734375
# INFO :      		round 8: 2.034230078125
# INFO :      		round 9: 1.77751953125
# INFO :      		round 10: 2.710341796875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0906),
# INFO :      	                   (1, 0.1936),
# INFO :      	                   (2, 0.4555),
# INFO :      	                   (3, 0.1599),
# INFO :      	                   (4, 0.2458),
# INFO :      	                   (5, 0.4601),
# INFO :      	                   (6, 0.5737),
# INFO :      	                   (7, 0.6921),
# INFO :      	                   (8, 0.8148),
# INFO :      	                   (9, 0.8589),
# INFO :      	                   (10, 0.8351)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">D</span>
#         <span>FedAdagrad</span>
#     </h3>
# </div>

# %%
#work good Beta1=beta2=0
TAU  = 0.2
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_adagrad_strategy = FedAdagrad(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
    tau=TAU
    )
fed_adagrad_server = Server(strategy=fed_adagrad_strategy, client_manager=SimpleClientManager())

# %%
fedadagrad_history = fl.simulation.start_simulation(
        server=fed_adagrad_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_adagrad_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 21:38:47,333	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'node:__internal_head__': 1.0, 'node:172.19.2.2': 1.0, 'memory': 18534528615.0, 'object_store_memory': 9267264307.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=18108) 2025-03-21 21:38:52.220621: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=18108) 2025-03-21 21:38:52.266502: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=18108) 2025-03-21 21:38:52.279901: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.3048630859375, {'test_accuracy': 0.1188}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2442267578125, {'test_accuracy': 0.2593}, 89.29568030899827)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.0509171875, {'test_accuracy': 0.4075}, 170.3604854979967)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.7346423828125, {'test_accuracy': 0.5372}, 249.9050778699966)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.3871072265625, {'test_accuracy': 0.6519}, 331.4871537689978)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.08094892578125, {'test_accuracy': 0.7356}, 411.20167118899917)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 0.8564546875, {'test_accuracy': 0.7856}, 491.9574785329969)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 0.6826791015625, {'test_accuracy': 0.8207}, 573.144679107998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.55237138671875, {'test_accuracy': 0.8487}, 656.0345853519975)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.468213330078125, {'test_accuracy': 0.8685}, 736.1938730169968)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.4039205078125, {'test_accuracy': 0.8801}, 819.9894486229969)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 821.79s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.2465436001635273
# INFO :      		round 2: 2.054308651804029
# INFO :      		round 3: 1.7399203931221472
# INFO :      		round 4: 1.3936960028249885
# INFO :      		round 5: 1.0905164060839223
# INFO :      		round 6: 0.8679887082797473
# INFO :      		round 7: 0.6957084596703905
# INFO :      		round 8: 0.5675589614355931
# INFO :      		round 9: 0.4825684530323401
# INFO :      		round 10: 0.4178972801832083
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3048630859375
# INFO :      		round 1: 2.2442267578125
# INFO :      		round 2: 2.0509171875
# INFO :      		round 3: 1.7346423828125
# INFO :      		round 4: 1.3871072265625
# INFO :      		round 5: 1.08094892578125
# INFO :      		round 6: 0.8564546875
# INFO :      		round 7: 0.6826791015625
# INFO :      		round 8: 0.55237138671875
# INFO :      		round 9: 0.468213330078125
# INFO :      		round 10: 0.4039205078125
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1188),
# INFO :      	                   (1, 0.2593),
# INFO :      	                   (2, 0.4075),
# INFO :      	                   (3, 0.5372),
# INFO :      	                   (4, 0.6519),
# INFO :      	                   (5, 0.7356),
# INFO :      	                   (6, 0.7856),
# INFO :      	                   (7, 0.8207),
# INFO :      	                   (8, 0.8487),
# INFO :      	                   (9, 0.8685),
# INFO :      	                   (10, 0.8801)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">E</span>
#         <span>FedYogi</span>
#     </h3>
# </div>

# %%
BETA1= 0.9
BETA2=0.99
net  = CNN( model_cfg["input_dim"], model_cfg["hidden_dims"],model_cfg["num_classes"])
initial_parameters = ndarrays_to_parameters([val.cpu().numpy() for _, val in net.state_dict().items()])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_adagrad_client_fn = gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS)
fed_adagrad_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_yogi_strategy = FedYogi(
        fraction_fit=1.0,  # Sample 100% of available clients for training
        fraction_evaluate=1.0,  # Sample 100% of available clients for evaluation
        min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
        min_evaluate_clients=NUM_CLIENTS,  # Never sample less than 5 clients for evaluation
        min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
        evaluate_fn=fed_adagrad_evaluate_fn,
        initial_parameters = initial_parameters,
     beta_1 =BETA_1,
        beta_2 = BETA_2,
    )
fed_yogi_server = Server(strategy=fed_yogi_strategy, client_manager=SimpleClientManager())

# %%
fedyogi_history = fl.simulation.start_simulation(
        server=fed_yogi_server,
        client_fn=fed_adagrad_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_yogi_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 21:52:41,139	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9267132825.0, 'CPU': 4.0, 'memory': 18534265652.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# (pid=18756) 2025-03-21 21:52:45.751464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=18756) 2025-03-21 21:52:45.797572: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=18756) 2025-03-21 21:52:45.812485: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      initial parameters (loss, other metrics): 2.3067728515625, {'test_accuracy': 0.0892}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2903216796875, {'test_accuracy': 0.1222}, 89.9434217579983)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 2.1988140625, {'test_accuracy': 0.3228}, 175.75898645199777)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.8916416015625, {'test_accuracy': 0.401}, 255.50770301999728)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.42771318359375, {'test_accuracy': 0.5042}, 334.473367863)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.1796376953125, {'test_accuracy': 0.6044}, 413.64346169800046)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 1.1088240234375, {'test_accuracy': 0.6916}, 493.5335472339975)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 1.09814267578125, {'test_accuracy': 0.7555}, 573.4947605550005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 1.03499765625, {'test_accuracy': 0.8044}, 653.3373453109998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.90296435546875, {'test_accuracy': 0.8456}, 732.818796632997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.789024951171875, {'test_accuracy': 0.8651}, 813.1402967459981)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 814.96s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.2891154506387466
# INFO :      		round 2: 2.1966970810401034
# INFO :      		round 3: 1.8843928995681267
# INFO :      		round 4: 1.405571723521203
# INFO :      		round 5: 1.1321077509459303
# INFO :      		round 6: 1.04291977349473
# INFO :      		round 7: 1.0134774707972356
# INFO :      		round 8: 0.9348638152559168
# INFO :      		round 9: 0.8007077090945515
# INFO :      		round 10: 0.7006280089073346
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3067728515625
# INFO :      		round 1: 2.2903216796875
# INFO :      		round 2: 2.1988140625
# INFO :      		round 3: 1.8916416015625
# INFO :      		round 4: 1.42771318359375
# INFO :      		round 5: 1.1796376953125
# INFO :      		round 6: 1.1088240234375
# INFO :      		round 7: 1.09814267578125
# INFO :      		round 8: 1.03499765625
# INFO :      		round 9: 0.90296435546875
# INFO :      		round 10: 0.789024951171875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0892),
# INFO :      	                   (1, 0.1222),
# INFO :      	                   (2, 0.3228),
# INFO :      	                   (3, 0.401),
# INFO :      	                   (4, 0.5042),
# INFO :      	                   (5, 0.6044),
# INFO :      	                   (6, 0.6916),
# INFO :      	                   (7, 0.7555),
# INFO :      	                   (8, 0.8044),
# INFO :      	                   (9, 0.8456),
# INFO :      	                   (10, 0.8651)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">F</span>
#         <span>FedNova</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_nova_client_fn = nova_gen_client_fn( trainloaders, valloaders,model_cfg,device,NUM_EPOCHS, LEARNING_RATE)
fed_nova_evaluate_fn = gen_evaluate_fn(testloader, 
                              device=device, model_cfg=model_cfg)

# %%
fed_nova_strategy =FedNovaStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_nova_evaluate_fn,
)

fed_nova_server = FedNovaServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_nova_strategy,
    )

# %%
fednova_history = fl.simulation.start_simulation(
        server=fed_nova_server,
        client_fn=fed_nova_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_nova_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 22:06:28,405	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'object_store_memory': 9267087360.0, 'CPU': 4.0, 'node:__internal_head__': 1.0, 'memory': 18534174720.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=19402) 2025-03-21 22:06:32.600931: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=19402) 2025-03-21 22:06:32.642428: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=19402) 2025-03-21 22:06:32.654646: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3030986328125, {'test_accuracy': 0.0896}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.837444921875, {'test_accuracy': 0.4479}, 77.59948191299918)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 1.12411865234375, {'test_accuracy': 0.7145}, 153.7453128140005)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 0.566158740234375, {'test_accuracy': 0.8473}, 232.57473036599913)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 0.3522135986328125, {'test_accuracy': 0.8888}, 309.8270549209992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 0.2551216552734375, {'test_accuracy': 0.9233}, 389.13790419900033)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 0.2053761474609375, {'test_accuracy': 0.9345}, 465.1010525579986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 0.168141650390625, {'test_accuracy': 0.9462}, 542.0795597020006)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 0.14370771484375, {'test_accuracy': 0.953}, 620.5342886690014)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 0.12796915283203125, {'test_accuracy': 0.9585}, 698.0627466580008)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 0.12201959228515626, {'test_accuracy': 0.9598}, 773.8929371429986)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 775.70s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.8310993618523708
# INFO :      		round 2: 1.1218349206636506
# INFO :      		round 3: 0.5649354873447243
# INFO :      		round 4: 0.35074601314582854
# INFO :      		round 5: 0.257549415388338
# INFO :      		round 6: 0.20413742636123033
# INFO :      		round 7: 0.17157613479961845
# INFO :      		round 8: 0.14312902086968218
# INFO :      		round 9: 0.13223270122660907
# INFO :      		round 10: 0.12706614226177396
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3030986328125
# INFO :      		round 1: 1.837444921875
# INFO :      		round 2: 1.12411865234375
# INFO :      		round 3: 0.566158740234375
# INFO :      		round 4: 0.3522135986328125
# INFO :      		round 5: 0.2551216552734375
# INFO :      		round 6: 0.2053761474609375
# INFO :      		round 7: 0.168141650390625
# INFO :      		round 8: 0.14370771484375
# INFO :      		round 9: 0.12796915283203125
# INFO :      		round 10: 0.12201959228515626
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0896),
# INFO :      	                   (1, 0.4479),
# INFO :      	                   (2, 0.7145),
# INFO :      	                   (3, 0.8473),
# INFO :      	                   (4, 0.8888),
# INFO :      	                   (5, 0.9233),
# INFO :      	                   (6, 0.9345),
# INFO :      	                   (7, 0.9462),
# INFO :      	                   (8, 0.953),
# INFO :      	                   (9, 0.9585),
# INFO :      	                   (10, 0.9598)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">G</span>
#         <span>FedScaffold</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
client_cv_dir = os.path.join("/kaggle/working/", "client_cvs")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_scaffold_client_fn =scaffold_gen_client_fn( trainloaders, valloaders,client_cv_dir,NUM_EPOCHS, LEARNING_RATE, model_cfg,device)
fed_scaffold_evaluate_fn = gen_evaluate_fn(testloader, 
                              device,model_cfg)

# %%
fed_scaffold_strategy =ScaffoldStrategy(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_scaffold_evaluate_fn,
)

fed_scaffold_server = ScaffoldServer(
        client_manager=SimpleClientManager(),  # Use a client manager
        strategy=fed_scaffold_strategy,
    model_cfg=model_cfg,
    )

# %%
fedscaffold_history = fl.simulation.start_simulation(
        server=fed_scaffold_server,
        client_fn=fed_scaffold_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_scaffold_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   Both server and strategy were provided, ignoring strategy
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 22:19:46,046	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18533272782.0, 'object_store_memory': 9266636390.0, 'node:__internal_head__': 1.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=20053) 2025-03-21 22:19:50.034652: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=20053) 2025-03-21 22:19:50.075734: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=20053) 2025-03-21 22:19:50.091103: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.3022974609375, {'test_accuracy': 0.1009}
# INFO :
# INFO :      [ROUND 1]
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 1.989998046875, {'test_accuracy': 0.2061}, 81.05614690100265)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      fit progress: (2, 1.7413158203125, {'test_accuracy': 0.6206}, 160.67645971300226)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      fit progress: (3, 1.6629345703125, {'test_accuracy': 0.6334}, 237.78977427499922)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      fit progress: (4, 1.6443849609375, {'test_accuracy': 0.5719}, 317.15926277700055)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      fit progress: (5, 1.624090234375, {'test_accuracy': 0.601}, 396.7047134480017)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      fit progress: (6, 1.629694140625, {'test_accuracy': 0.4077}, 473.6800325969998)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      fit progress: (7, 1.61634716796875, {'test_accuracy': 0.4102}, 556.2869199930028)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      fit progress: (8, 1.6445095703125, {'test_accuracy': 0.3237}, 636.4600510730015)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      fit progress: (9, 1.6347681640625, {'test_accuracy': 0.3354}, 713.5907795910025)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      fit progress: (10, 1.6939046875, {'test_accuracy': 0.2955}, 796.4852008890011)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 798.43s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.9798012941852026
# INFO :      		round 2: 1.7443419708621015
# INFO :      		round 3: 1.6633219913008612
# INFO :      		round 4: 1.6483666041376592
# INFO :      		round 5: 1.6279880859734517
# INFO :      		round 6: 1.635739565253556
# INFO :      		round 7: 1.6240581700561243
# INFO :      		round 8: 1.6512112674363162
# INFO :      		round 9: 1.6432677675029255
# INFO :      		round 10: 1.701290410911172
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.3022974609375
# INFO :      		round 1: 1.989998046875
# INFO :      		round 2: 1.7413158203125
# INFO :      		round 3: 1.6629345703125
# INFO :      		round 4: 1.6443849609375
# INFO :      		round 5: 1.624090234375
# INFO :      		round 6: 1.629694140625
# INFO :      		round 7: 1.61634716796875
# INFO :      		round 8: 1.6445095703125
# INFO :      		round 9: 1.6347681640625
# INFO :      		round 10: 1.6939046875
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1009),
# INFO :      	                   (1, 0.2061),
# INFO :      	                   (2, 0.6206),
# INFO :      	                   (3, 0.6334),
# INFO :      	                   (4, 0.5719),
# INFO :      	                   (5, 0.601),
# INFO :      	                   (6, 0.4077),
# INFO :      	                   (7, 0.4102),
# INFO :      	                   (8, 0.3237),
# INFO :      	                   (9, 0.3354),
# INFO :      	                   (10, 0.2955)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">H</span>
#         <span>FedMoon</span>
#     </h3>
# </div>

# %%
model_cfg = {
        "input_dim": 256,
        "hidden_dims": [120, 84],
        "output_dim": 256,
        "num_classes": 10,}
backend_config =  {"num_cpus": 1, "num_gpus": 0}
MU = 5
TEMPERATURE = 0.5
MODEL_DIR = os.path.join("/kaggle/working/", "models")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fed_moon_client_fn =moon_gen_client_fn( trainloaders, valloaders,device,model_cfg,NUM_EPOCHS,
                                       LEARNING_RATE, MU,TEMPERATURE,MODEL_DIR)
fed_moon_evaluate_fn = moon_gen_evaluate_fn(testloader, 
                             device,model_cfg)

# %%
fed_moon_strategy =fl.server.strategy.FedAvg(
      fraction_fit = 1,
        fraction_evaluate= 1,
        min_fit_clients= NUM_CLIENTS,
        min_available_clients=NUM_CLIENTS,
        min_evaluate_clients=NUM_CLIENTS,
    evaluate_fn=fed_moon_evaluate_fn,
)

# %%
fedmoon_history = fl.simulation.start_simulation(
        client_fn=fed_moon_client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=fed_moon_strategy,
    client_resources = backend_config
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-03-21 22:33:25,902	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.19.2.2': 1.0, 'memory': 18559281563.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9279640780.0, 'CPU': 4.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=20703) 2025-03-21 22:33:30.012923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=20702) 2025-03-21 22:33:30.127071: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=20702) 2025-03-21 22:33:30.140205: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.305298089981079, {'test_accuracy': 0.1009}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 2.2255918979644775, {'test_accuracy': 0.2845}, 151.98870611700113)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (2, 1.4727580547332764, {'test_accuracy': 0.4205}, 294.87334414600264)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (3, 1.1768271923065186, {'test_accuracy': 0.6305}, 445.7902051650017)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (4, 1.1024528741836548, {'test_accuracy': 0.6563}, 590.9419085750014)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (5, 1.266433835029602, {'test_accuracy': 0.6553}, 737.4333821309992)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (6, 1.0668976306915283, {'test_accuracy': 0.6872}, 888.3438257830021)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (7, 1.0388355255126953, {'test_accuracy': 0.7131}, 1039.1059997770026)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (8, 0.9143213033676147, {'test_accuracy': 0.7607}, 1185.0105591610009)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (9, 0.5064677000045776, {'test_accuracy': 0.8143}, 1332.3739686879999)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      fit progress: (10, 0.4074687063694, {'test_accuracy': 0.8251}, 1480.5069388049997)
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 1482.07s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.305298089981079
# INFO :      		round 1: 2.2255918979644775
# INFO :      		round 2: 1.4727580547332764
# INFO :      		round 3: 1.1768271923065186
# INFO :      		round 4: 1.1024528741836548
# INFO :      		round 5: 1.266433835029602
# INFO :      		round 6: 1.0668976306915283
# INFO :      		round 7: 1.0388355255126953
# INFO :      		round 8: 0.9143213033676147
# INFO :      		round 9: 0.5064677000045776
# INFO :      		round 10: 0.4074687063694
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1009),
# INFO :      	                   (1, 0.2845),
# INFO :      	                   (2, 0.4205),
# INFO :      	                   (3, 0.6305),
# INFO :      	                   (4, 0.6563),
# INFO :      	                   (5, 0.6553),
# INFO :      	                   (6, 0.6872),
# INFO :      	                   (7, 0.7131),
# INFO :      	                   (8, 0.7607),
# INFO :      	                   (9, 0.8143),
# INFO :      	                   (10, 0.8251)]}
# INFO :

# %% [markdown]
# <a id='331'></a>
# <div style="border-left: 6px solid #3498db; border-radius: 0 15px 15px 0; padding: 15px; margin: 20px 0 20px 60px; box-shadow: 3px 3px 10px rgba(0,0,0,0.1); background: linear-gradient(to right, #F5F8FA, #EBF5FB);">
#     <h3 style="font-size: 22px; font-weight: bold; color: #34495E; font-family: 'Arial'; margin: 0; display: flex; align-items: center;">
#         <span style="background-color: #F1C40F; color: #0E6655; padding: 2px 8px; border-radius: 8px; margin-right: 12px; font-size: 18px; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">L</span>
#         <span>Learning Curve: Test Accuracy vs. Communication Rounds</span>
#     </h3>
# </div>

# %%
plot_federated_learning_curves(
    fedavg_history,
    fedprox_history,
    fedadam_history,
    fedadagrad_history,
    fedyogi_history,
    fednova_history,
    fedscaffold_history,
    fedmoon_history,
    save_plot=True,
    filename='label Skew C_3.png'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
